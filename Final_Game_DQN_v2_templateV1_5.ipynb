# %%
import pygame
import os
import sys

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
from PIL import Image
import random
import matplotlib.pyplot as plt
from matplotlib import animation
from collections import deque

script_dir = os.path.join(os.getcwd(), 'space_ship_game_RL')
if script_dir not in sys.path:
    sys.path.append(script_dir)

from setting import *
from game import Game
# Out:
# pygame 2.2.0 (SDL 2.32.54, Python 3.11.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
print(torch.cuda.is_available())  # 應該為 True
print(torch.version.cuda)         # 應該列出 CUDA 版本
print(torch.backends.cudnn.version())  # cuDNN 版本
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# True
# 11.8
# 90100
# Using device: cuda

# %%
# Hyperparameters (維持不變)
num_episodes = 4000
batch_size = 128000
gamma = 0.99
lr = 5e-5
epsilon_start = 1.0
epsilon_end = 0.01
epsilon_decay = 0.9995
memory_capacity = 128000
target_update_freq = 100 
epsilon_list=[]
epsilon=epsilon_start
for i in range(num_episodes):
    epsilon = max(epsilon_end, epsilon * epsilon_decay)
    epsilon_list.append(epsilon)
plt.plot(epsilon_list)

# %%
# CNN-based DQN Model
class DQN(nn.Module):
    def __init__(self, num_actions):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(64 * 7 * 7, 512)
        self.fc2 = nn.Linear(512, num_actions)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# Replay buffer
# 用於儲存代理人經驗（狀態、動作、獎勵等）的緩衝區，支援隨機抽樣以打破時間相關性，有助於穩定訓練。
class ReplayMemory:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
        # Use deque with a fixed capacity to automatically discard the oldest experience when full.
        # 使用 deque 並設定最大長度，當容量滿時會自動移除最舊的資料。

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))
        # Store a single transition (experience) in the buffer.
        # 儲存一筆經驗（狀態轉移）進緩衝區。

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        # Randomly sample a batch of transitions to break correlation between consecutive samples.
        # 隨機抽取一批經驗，打破樣本間的時間關聯性，提高訓練穩定性。

        # Unpack each element into separate tensors for network input
        # 將 batch 拆解成分別的 tensor 以供神經網路訓練
        states, actions, rewards, next_states, dones = zip(*batch)
        
        # Convert the sampled data into tensors and move them to the specified device (CPU or GPU)
        # 將抽樣資料轉成 tensor 並移至指定設備（CPU/GPU）
        states = torch.tensor(np.stack(states), dtype=torch.float32, device=device)
        actions = torch.tensor(actions, dtype=torch.int64, device=device)
        rewards = torch.tensor(rewards, dtype=torch.float32, device=device)
        next_states = torch.tensor(np.stack(next_states), dtype=torch.float32, device=device)
        dones = torch.tensor(dones, dtype=torch.float32, device=device)
        
        return states, actions, rewards, next_states, dones

    def __len__(self):
        return len(self.buffer)
        # Return the current size of the buffer.
        # 回傳緩衝區目前儲存的資料數量。
# Preprocess frames (grayscale and resize to 84x84)
# 預處理影格：轉為灰階並縮放為 84x84

def preprocess_frame(frame):
    # frame 是 numpy array (H, W, 3)，先轉為 PIL Image
    # Input is a color image (RGB), convert to PIL format for easier processing.
    # 輸入是彩色圖像（RGB），轉成 PIL Image 以方便處理。
    image = Image.fromarray(frame)

    # 轉灰階
    # Convert the image to grayscale to reduce input complexity.
    # 將影像轉為灰階，降低輸入維度與計算量。
    image = image.convert('L')

    # resize 成 84x84
    # Resize the image to a standard 84x84 shape, as per DQN convention.
    # 依照 DQN 的慣例將影像統一縮放至 84x84。
    image = image.resize((84, 84), Image.Resampling.BILINEAR)  # or NEAREST, or LANCZOS

    # 轉回 numpy 並正規化
    # Convert back to NumPy and normalize pixel values to [0, 1].
    # 轉回 NumPy 格式並將像素值標準化到 [0, 1]。
    frame = np.asarray(image, dtype=np.float32) / 255.0

    return frame


def stack_frames(stacked_frames, state, is_new_episode):
    # 預處理目前影格
    frame = preprocess_frame(state)

    if is_new_episode or stacked_frames is None:
        # If it's a new episode or no previous frames, initialize with 4 identical frames
        # 若是新的一集或是尚未初始化，則用目前影格複製 4 次形成初始堆疊
        stacked_frames = deque([frame]*4, maxlen=4)
    else:
        # 否則把新影格加入到堆疊中，自動捨棄最舊的
        stacked_frames.append(frame)

    # Stack the 4 frames along the first dimension: shape becomes (4, 84, 84)
    # 沿著第一維（channel）堆疊成 4 通道輸入：形狀變成 (4, 84, 84)
    stacked_state = np.stack(stacked_frames, axis=0)

    return stacked_state, stacked_frames

# %%
class SpaceShipEnv():
    def __init__(self, frame_skip=4, stack_frames=4):
        pygame.init()
        # pygame.font.init() # 如果不在 env 中顯示文字，可以不用初始化

        self.screen = None 
        self.clock = pygame.time.Clock()
        self.fps = FPS

        self.game = Game() # 遊戲邏輯實例

        # 動作空間: 0: 不動, 1: 左, 2: 右, 3: 射擊
        self.action_space = [0, 1, 2, 3] 
        self.action_space_n = len(self.action_space)

        # 幀處理相關
        self.frame_skip = frame_skip
        self.stack_frames = stack_frames
        self.frame_buffer = deque(maxlen=self.stack_frames)

        self.frames_since_last_shot = 0
        self.SHOT_COOLDOWN_FRAMES = 60 # 假設子彈冷卻時間為 60 幀
        
        # 定義中間區域的範圍
        self.CENTER_ZONE_WIDTH_PERCENT = 0.5 # 中間 20% 的區域
        self.CENTER_ZONE_X_START = WIDTH * (0.5 - self.CENTER_ZONE_WIDTH_PERCENT / 2)
        self.CENTER_ZONE_X_END = WIDTH * (0.5 + self.CENTER_ZONE_WIDTH_PERCENT / 2)
        # ## 新增: 勝利條件分數 ##
        self.WIN_SCORE = 10000 

    def step(self, action):
        """
        執行一個動作，並回傳 (下一個狀態, 獎勵, 遊戲是否結束, 當前分數)
        """
        total_reward = 0.0
        done = False

        # --- 狀態追蹤 (State Tracking) ---
        # 在 action 執行前，記錄當前的狀態，以便後續計算獎勵
        prev_health = self.game.player.sprite.health
        prev_score = self.game.score
        prev_is_power = self.game.is_power 
        # --- 執行動作 (Action Execution) ---
        # 根據 frame_skip 的設定，重複執行同一個動作
        for _ in range(self.frame_skip):
            self.game.update(action) 
            
            # ## 優化 ##
            # 除非需要渲染畫面來獲取狀態，否則 draw 是不必要的。
            # 這裡假設 self.game.update() 會更新 self.game.state
            # 如果不是，則保留 self.game.draw(None)
            
            # 檢查遊戲是否在任何一幀結束
            if not self.game.running:
                done = True
                break

        # --- 獎勵計算 (Reward Calculation) ---
        # 在所有幀都執行完畢後，根據「狀態的變化」來計算總獎勵
        
        # 1. 主要獎勵：分數增益 (Score Gain)
        current_score = self.game.score
        current_is_power = self.game.is_power # 獲取最新的 is_power 狀態
        current_health = self.game.player.sprite.health # 獲取最新的健康值
        current_is_hit_rock = self.game.is_hit_rock # 獲取最新的是否擊中石頭狀態

        score_gain = current_score - prev_score
        if score_gain > 0:
            # 將分數的增益直接轉換為獎勵，權重可以調整
            # 這樣 Agent 會自然學會優先攻擊分數較高的石頭 (通常更大、更危險)
            total_reward += score_gain * 0.5  # 權重是超參數，可以實驗調整 🎮
            
            # 根據分數增益給予額外的大石頭獎勵，與 1_2 版本對齊
            if score_gain >= 40: # 超大型石頭 (例如半徑 ~40)
                total_reward += 10.0 
            elif score_gain >= 15: # 大型石頭 (例如半徑 ~18)
                total_reward += 5.0 
            elif score_gain >= 5: # 中型石頭
                total_reward += 3 
            else: # 小型石頭
                total_reward += 2 

        # 2. 主要懲罰：生命值損失 (Health Loss)
        health_diff = current_health - prev_health
        if health_diff < 0: # 掉血懲罰
            total_reward -= abs(health_diff) * 1.5  # 固定的高額懲罰 🩸 (使用 abs 以便計算正數)
        elif health_diff > 0: # 補血獎勵
            total_reward += health_diff * 1.5 # 補血有獎勵！🩹

        # 3. 行為塑造：射擊成本 (Shooting Cost) 及擊中獎勵
        if action == 3: # 假設 3 是射擊
            if self.frames_since_last_shot < self.SHOT_COOLDOWN_FRAMES:
                total_reward -= 2.5 # 冷卻中射擊懲罰大幅提高！❌
            else:
                self.frames_since_last_shot = 0 # 重置射擊冷卻計時器
                if current_is_hit_rock and score_gain > 0: # 射擊並成功擊中石頭並得分
                    total_reward += 10 # 成功射擊本身有小獎勵
                else: # 亂射或沒擊中
                    total_reward -= 5 # 亂射懲罰再高一點 🎯

        # 4. 行為塑造：生存獎勵 (Survival Reward)
        if not done:
            total_reward += 0.5

        # 5. 終局獎勵/懲罰 (Terminal Reward/Penalty)
        if done:
            if current_health <= 0: # 因為死亡導致遊戲結束
                total_reward -= 500.0 # 死亡的懲罰，比單次受傷更重！💀
            if current_score >= self.WIN_SCORE: # 勝利條件達成
                total_reward += 10000.0 # 勝利的喜悅！🎉

        # 吃到寶物獎勵
        if current_is_power and not prev_is_power: 
            total_reward += 30 # 吃到寶物給予獎勵 ✨ (調整為 20 以與 1_2 更接近)

        # 中間區域額外獎勵 (調整為與 1_2 相同邏輯)
        ship_center_x = self.game.player.sprite.rect.centerx 
        if ship_center_x >= self.CENTER_ZONE_X_START and \
           ship_center_x <= self.CENTER_ZONE_X_END: # 不再需要判斷是否有最佳射擊目標和子彈準備好
            total_reward += 0.3 # 鼓勵保持在中心 🎯

        # 新增：基於總分數的額外獎勵 (每次 step 都給予，但權重可以很小)
        if self.game.score > 0:
            reward_for_total_score = self.game.score * 0.005 # 舉例值，需要實驗調整！💡
            total_reward += reward_for_total_score

        # --- 狀態處理 (State Processing) ---
        # 這部分邏輯與您原本的設計相同，非常棒！
        current_raw_frame = self.game.state
        processed_frame = preprocess_frame(current_raw_frame)
        self.frame_buffer.append(processed_frame)
        
        # 確保 buffer 在遊戲一開始就能填滿
        while len(self.frame_buffer) < self.stack_frames:
            self.frame_buffer.append(processed_frame)
            
        stacked_state = np.array(list(self.frame_buffer))

        # info 通常是一個字典，可用來傳遞除錯資訊，這裡我們先簡單回傳分數
        info = {'score': self.game.score}

        return stacked_state, total_reward, done, info

    def reset(self):
        # Reset 函數的邏輯很完美，不需要大改
        self.game = Game()
        self.frame_buffer.clear()
        
        # 填充初始的 frame buffer
        for _ in range(self.stack_frames):
            initial_raw_state = self.game.state 
            processed_frame = preprocess_frame(initial_raw_state) 
            self.frame_buffer.append(processed_frame)
        
        stacked_state = np.array(list(self.frame_buffer))
        return stacked_state

    def render(self):
        # Render 函數的邏輯很完美，不需要修改
        if self.screen is None:
            self.screen = pygame.display.set_mode((WIDTH, HEIGHT))
            pygame.display.set_caption("SpaceShip RL Environment")

        # 讓視窗可以被關閉
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                self.close()
                sys.exit()

        self.game.draw(self.screen) 
        pygame.display.update()
        self.clock.tick(self.fps)

    def close(self):
        pygame.quit()

# %%
for i in range(100):
    # Hyperparameters (維持不變)
    num_episodes = 50000
    batch_size = 64
    gamma = 0.99
    lr = 5e-5
    epsilon_start = 1.0
    epsilon_end = 0.01
    epsilon_decay = 0.9995
    memory_capacity = 128000
    target_update_freq = 1000

    # 初始化 Breakout 環境 
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # 確保 device 有定義
    env = SpaceShipEnv(frame_skip=2, stack_frames=4) # 明確指定 frame_skip 和 stack_frames
    num_actions = len(env.action_space)

    # 建立策略網路與目標網路
    policy_net = DQN(num_actions).to(device)
    target_net = DQN(num_actions).to(device)
    target_net.load_state_dict(policy_net.state_dict()) 
    target_net.eval()

    optimizer = optim.Adam(policy_net.parameters(), lr=lr)
    memory = ReplayMemory(memory_capacity)

    # 載入模型（若有）
    if os.path.exists('checkpoint.pth'):
        checkpoint = torch.load('checkpoint.pth', map_location=device)
        policy_net.load_state_dict(checkpoint['policy_net'])
        target_net.load_state_dict(checkpoint['target_net'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        start_episode = checkpoint['episode'] + 1
        total_steps = checkpoint['total_steps']
        best_score = checkpoint['best_score']
        epsilon = checkpoint['epsilon']
        reward_history = checkpoint['reward_history']
        score_history = checkpoint['score_history']
        print(f"Loaded checkpoint from episode {start_episode}, best score: {best_score:.2f}, epsilon={epsilon:.3f}")
    else:
        start_episode = 0
        total_steps = 0
        best_score = float('-inf')
        epsilon = epsilon_start
        reward_history = []
        score_history = []


    # 訓練迴圈
    for episode in range(start_episode, num_episodes + 1): 
        # env.reset() 現在會直接返回堆疊好的狀態
        state = env.reset() 
        # 移除這行，因為 stacked_frames 不再需要，且 stack_frames 函數已移除
        # state, stacked_frames = stack_frames(None, state, True) 
        total_reward, done = 0, False

        while not done:
            # ε-greedy 策略
            if random.random() < epsilon:
                action = random.choice(env.action_space)
            else:
                with torch.no_grad():
                    # state 已經是 (4, 84, 84)，需要 unsqueeze(0) 變成 (1, 4, 84, 84)
                    state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
                    action = policy_net(state_tensor).argmax(dim=1).item()

            # 執行動作，env.step 返回的 next_state 也是堆疊好的狀態
            # ==================== 主要修改處 ====================
            # 執行動作，正確接收 info 字典
            next_state, reward, done_, info = env.step(action)
            # 從 info 字典中提取當前的分數
            score = info['score']
            # ==================================================
            done = done_
            total_reward += reward

            # 移除這行，因為 stacked_frames 不再需要
            # next_state, stacked_frames = stack_frames(stacked_frames, next_state, False) 
            memory.push(state, action, reward, next_state, done)
            state = next_state

            # 訓練模型
            if len(memory) >= batch_size:
                states, actions, rewards, next_states, dones = memory.sample(batch_size)

                with torch.no_grad():
                    target_q = rewards + gamma * target_net(next_states).max(1)[0] * (1 - dones)

                current_q = policy_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)
                loss = F.mse_loss(current_q, target_q)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            # 更新 target 網路
            total_steps += 1
            if total_steps % target_update_freq == 0:
                target_net.load_state_dict(policy_net.state_dict())
            
            if episode % 20 == 0 and total_steps % 4 == 0: # <-- 建議從這裡開始測試
                env.render() 

        # 更新 epsilon 並紀錄統計資料
        epsilon = max(epsilon_end, epsilon * epsilon_decay)
        reward_history.append(total_reward)
        score_history.append(score)

        print(f"Episode {episode + 1:3d}, Reward: {total_reward:7.2f}, Score: {score:4d}, Epsilon: {epsilon:5.3f}")

        # 儲存模型
        if (episode + 1) % 20 == 0 or score > best_score:
            best_score = max(best_score, score)

            torch.save({
                'policy_net': policy_net.state_dict(),
                'target_net': target_net.state_dict(),
                'optimizer': optimizer.state_dict(),
                'epsilon': epsilon,
                'episode': episode,
                'total_steps': total_steps,
                'best_score': best_score,
                'reward_history': reward_history,
                'score_history': score_history,
            }, 'checkpoint.pth')

            print(f"Checkpoint saved at episode {episode + 1}, best score: {best_score:.2f}")
            break

    # env.close()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9580\2480029514.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('checkpoint.pth', map_location=device)
# Loaded checkpoint from episode 7860, best score: 5848.00, epsilon=0.020
# Episode 7861, Reward: -441.05, Score:  170, Epsilon: 0.020
# Episode 7862, Reward: -384.53, Score:  502, Epsilon: 0.020
# Episode 7863, Reward:  340.75, Score:  944, Epsilon: 0.020
# Episode 7864, Reward: 4935.02, Score: 1948, Epsilon: 0.020
# Episode 7865, Reward:  352.67, Score:  872, Epsilon: 0.020
# Episode 7866, Reward: 3179.76, Score: 1550, Epsilon: 0.020
# Episode 7867, Reward: -519.71, Score:  464, Epsilon: 0.020
# Episode 7868, Reward: -743.78, Score:  334, Epsilon: 0.020
# Episode 7869, Reward: 5754.52, Score: 2170, Epsilon: 0.020
# Episode 7870, Reward:  342.72, Score:  860, Epsilon: 0.020
# Episode 7871, Reward: -715.69, Score:  280, Epsilon: 0.020
# Episode 7872, Reward:  632.86, Score:  986, Epsilon: 0.020
# Episode 7873, Reward: -890.80, Score:  280, Epsilon: 0.019
# Episode 7874, Reward: -534.90, Score:  472, Epsilon: 0.019
# Episode 7875, Reward: 11195.97, Score: 2772, Epsilon: 0.019
# Episode 7876, Reward: -434.43, Score:  678, Epsilon: 0.019
# Episode 7877, Reward: 1519.55, Score: 1222, Epsilon: 0.019
# Episode 7878, Reward: -220.54, Score:  614, Epsilon: 0.019
# Episode 7879, Reward:  213.06, Score:  894, Epsilon: 0.019
# Episode 7880, Reward: -837.75, Score:  278, Epsilon: 0.019
# Checkpoint saved at episode 7880, best score: 5848.00
# Loaded checkpoint from episode 7880, best score: 5848.00, epsilon=0.019
# Episode 7881, Reward: -508.86, Score:  202, Epsilon: 0.019
# Episode 7882, Reward: -391.58, Score:  612, Epsilon: 0.019
# Episode 7883, Reward: -450.26, Score:  574, Epsilon: 0.019
# Episode 7884, Reward:    2.45, Score:  654, Epsilon: 0.019
# Episode 7885, Reward: -417.55, Score:  100, Epsilon: 0.019
# Episode 7886, Reward: -582.30, Score:    0, Epsilon: 0.019
# Episode 7887, Reward: -749.75, Score:  176, Epsilon: 0.019
# Episode 7888, Reward: -636.36, Score:  314, Epsilon: 0.019
# Episode 7889, Reward: -258.09, Score:  240, Epsilon: 0.019
# Episode 7890, Reward: -533.10, Score:    0, Epsilon: 0.019
# Episode 7891, Reward: -364.80, Score:  118, Epsilon: 0.019
# Episode 7892, Reward: -212.70, Score:  236, Epsilon: 0.019
# Episode 7893, Reward:  421.25, Score:  404, Epsilon: 0.019
# Episode 7894, Reward: -608.90, Score:    0, Epsilon: 0.019
# Episode 7895, Reward:  534.26, Score:  370, Epsilon: 0.019
# Episode 7896, Reward: -496.18, Score:   70, Epsilon: 0.019
# Episode 7897, Reward: -593.80, Score:    0, Epsilon: 0.019
# Episode 7898, Reward: -315.30, Score:  260, Epsilon: 0.019
# Episode 7899, Reward: -261.13, Score:  270, Epsilon: 0.019
# Episode 7900, Reward: -448.29, Score:   28, Epsilon: 0.019
# Checkpoint saved at episode 7900, best score: 5848.00
# Loaded checkpoint from episode 7900, best score: 5848.00, epsilon=0.019
# Episode 7901, Reward: -228.80, Score:  280, Epsilon: 0.019
# Episode 7902, Reward: -459.90, Score:    0, Epsilon: 0.019
# Episode 7903, Reward: -500.85, Score:   50, Epsilon: 0.019
# Episode 7904, Reward: -476.30, Score:    0, Epsilon: 0.019
# Episode 7905, Reward: -411.02, Score:   66, Epsilon: 0.019
# Episode 7906, Reward: -379.93, Score:   82, Epsilon: 0.019
# Episode 7907, Reward: -478.84, Score:   42, Epsilon: 0.019
# Episode 7908, Reward: -489.89, Score:   42, Epsilon: 0.019
# Episode 7909, Reward: -414.78, Score:   18, Epsilon: 0.019
# Episode 7910, Reward: -272.00, Score:   50, Epsilon: 0.019
# Episode 7911, Reward: -583.50, Score:    0, Epsilon: 0.019
# Episode 7912, Reward: -457.30, Score:    0, Epsilon: 0.019
# Episode 7913, Reward: -443.62, Score:   16, Epsilon: 0.019
# Episode 7914, Reward: -533.70, Score:    0, Epsilon: 0.019
# Episode 7915, Reward: -450.20, Score:   20, Epsilon: 0.019
# Episode 7916, Reward: -488.88, Score:   42, Epsilon: 0.019
# Episode 7917, Reward: -364.39, Score:   34, Epsilon: 0.019
# Episode 7918, Reward: -397.15, Score:  120, Epsilon: 0.019
# Episode 7919, Reward: -147.62, Score:  266, Epsilon: 0.019
# Episode 7920, Reward: -716.81, Score:  184, Epsilon: 0.019
# Checkpoint saved at episode 7920, best score: 5848.00
# Loaded checkpoint from episode 7920, best score: 5848.00, epsilon=0.019
# Episode 7921, Reward: -457.72, Score:  228, Epsilon: 0.019
# Episode 7922, Reward: -552.30, Score:    0, Epsilon: 0.019
# Episode 7923, Reward: -431.66, Score:   32, Epsilon: 0.019
# Episode 7924, Reward: -425.62, Score:   78, Epsilon: 0.019
# Episode 7925, Reward: -484.22, Score:   18, Epsilon: 0.019
# Episode 7926, Reward:  -65.19, Score:  336, Epsilon: 0.019
# Episode 7927, Reward: -451.76, Score:   16, Epsilon: 0.019
# Episode 7928, Reward: -412.21, Score:  238, Epsilon: 0.019
# Episode 7929, Reward: -455.54, Score:  136, Epsilon: 0.019
# Episode 7930, Reward:  426.48, Score:  646, Epsilon: 0.019
# Episode 7931, Reward: -274.41, Score:  242, Epsilon: 0.019
# Episode 7932, Reward:  -55.33, Score:  192, Epsilon: 0.019
# Episode 7933, Reward:  -94.36, Score:  202, Epsilon: 0.019
# Episode 7934, Reward: -445.10, Score:  100, Epsilon: 0.019
# Episode 7935, Reward: -476.70, Score:   70, Epsilon: 0.019
# Episode 7936, Reward: -458.83, Score:   76, Epsilon: 0.019
# Episode 7937, Reward:  215.89, Score:  428, Epsilon: 0.019
# Episode 7938, Reward: -473.70, Score:  246, Epsilon: 0.019
# Episode 7939, Reward: -258.33, Score:  150, Epsilon: 0.019
# Episode 7940, Reward: -410.95, Score:   94, Epsilon: 0.019
# Checkpoint saved at episode 7940, best score: 5848.00
# Loaded checkpoint from episode 7940, best score: 5848.00, epsilon=0.019
# Episode 7941, Reward: -348.98, Score:  188, Epsilon: 0.019
# Episode 7942, Reward: -510.30, Score:    0, Epsilon: 0.019
# Episode 7943, Reward: -486.80, Score:    0, Epsilon: 0.019
# Episode 7944, Reward: -521.30, Score:    0, Epsilon: 0.019
# Episode 7945, Reward: -531.30, Score:    0, Epsilon: 0.019
# Episode 7946, Reward: -327.22, Score:   58, Epsilon: 0.019
# Episode 7947, Reward: -514.75, Score:   10, Epsilon: 0.019
# Episode 7948, Reward: -389.46, Score:   42, Epsilon: 0.019
# Episode 7949, Reward: -577.26, Score:   16, Epsilon: 0.019
# Episode 7950, Reward: -390.58, Score:   32, Epsilon: 0.019
# Episode 7951, Reward: -479.91, Score:   42, Epsilon: 0.019
# Episode 7952, Reward: -586.30, Score:    0, Epsilon: 0.019
# Episode 7953, Reward: -431.94, Score:   16, Epsilon: 0.019
# Episode 7954, Reward: -101.25, Score:  130, Epsilon: 0.019
# Episode 7955, Reward: -446.30, Score:    0, Epsilon: 0.019
# Episode 7956, Reward: -481.76, Score:   18, Epsilon: 0.019
# Episode 7957, Reward: -388.97, Score:   66, Epsilon: 0.019
# Episode 7958, Reward: -365.90, Score:   20, Epsilon: 0.019
# Episode 7959, Reward: -521.30, Score:    0, Epsilon: 0.019
# Episode 7960, Reward: -146.93, Score:  134, Epsilon: 0.019
# Checkpoint saved at episode 7960, best score: 5848.00
# Loaded checkpoint from episode 7960, best score: 5848.00, epsilon=0.019
# Episode 7961, Reward: -399.73, Score:  186, Epsilon: 0.019
# Episode 7962, Reward: -465.80, Score:   18, Epsilon: 0.019
# Episode 7963, Reward: -434.25, Score:   26, Epsilon: 0.019
# Episode 7964, Reward: -439.76, Score:   18, Epsilon: 0.019
# Episode 7965, Reward: -476.55, Score:   50, Epsilon: 0.019
# Episode 7966, Reward: -378.04, Score:   16, Epsilon: 0.019
# Episode 7967, Reward: -514.80, Score:    0, Epsilon: 0.019
# Episode 7968, Reward: -582.80, Score:    0, Epsilon: 0.019
# Episode 7969, Reward: -538.80, Score:    0, Epsilon: 0.019
# Episode 7970, Reward: -212.66, Score:   92, Epsilon: 0.019
# Episode 7971, Reward: -591.30, Score:    0, Epsilon: 0.019
# Episode 7972, Reward: -541.30, Score:    0, Epsilon: 0.019
# Episode 7973, Reward: -469.20, Score:   20, Epsilon: 0.019
# Episode 7974, Reward: -414.28, Score:   16, Epsilon: 0.019
# Episode 7975, Reward: -396.16, Score:   42, Epsilon: 0.019
# Episode 7976, Reward: -277.94, Score:   16, Epsilon: 0.019
# Episode 7977, Reward: -525.80, Score:    0, Epsilon: 0.019
# Episode 7978, Reward: -568.80, Score:    0, Epsilon: 0.018
# Episode 7979, Reward: -431.55, Score:   50, Epsilon: 0.018
# Episode 7980, Reward: -102.74, Score:   70, Epsilon: 0.018
# Checkpoint saved at episode 7980, best score: 5848.00
# Loaded checkpoint from episode 7980, best score: 5848.00, epsilon=0.018
# Episode 7981, Reward: -543.34, Score:   58, Epsilon: 0.018
# Episode 7982, Reward: -499.51, Score:   42, Epsilon: 0.018
# Episode 7983, Reward: -268.55, Score:   50, Epsilon: 0.018
# Episode 7984, Reward: -222.66, Score:   68, Epsilon: 0.018
# Episode 7985, Reward: -238.84, Score:  160, Epsilon: 0.018
# Episode 7986, Reward: -544.80, Score:    0, Epsilon: 0.018
# Episode 7987, Reward: -439.30, Score:   50, Epsilon: 0.018
# Episode 7988, Reward:  494.37, Score:  124, Epsilon: 0.018
# Episode 7989, Reward: -422.38, Score:   16, Epsilon: 0.018
# Episode 7990, Reward: -412.98, Score:   42, Epsilon: 0.018
# Episode 7991, Reward: -553.80, Score:    0, Epsilon: 0.018
# Episode 7992, Reward: -529.05, Score:   10, Epsilon: 0.018
# Episode 7993, Reward: -430.75, Score:   42, Epsilon: 0.018
# Episode 7994, Reward: -470.65, Score:   10, Epsilon: 0.018
# Episode 7995, Reward: -540.30, Score:    0, Epsilon: 0.018
# Episode 7996, Reward: -469.60, Score:   10, Epsilon: 0.018
# Episode 7997, Reward: -483.80, Score:    0, Epsilon: 0.018
# Episode 7998, Reward: -409.71, Score:  110, Epsilon: 0.018
# Episode 7999, Reward: -479.05, Score:   10, Epsilon: 0.018
# Episode 8000, Reward: -425.95, Score:   10, Epsilon: 0.018
# Checkpoint saved at episode 8000, best score: 5848.00
# Loaded checkpoint from episode 8000, best score: 5848.00, epsilon=0.018
# Episode 8001, Reward: -180.33, Score:  274, Epsilon: 0.018
# Episode 8002, Reward: -219.11, Score:   92, Epsilon: 0.018
# Episode 8003, Reward: -490.70, Score:    0, Epsilon: 0.018
# Episode 8004, Reward: -277.55, Score:   50, Epsilon: 0.018
# Episode 8005, Reward: -477.41, Score:   18, Epsilon: 0.018
# Episode 8006, Reward: -574.30, Score:    0, Epsilon: 0.018
# Episode 8007, Reward: -521.30, Score:    0, Epsilon: 0.018
# Episode 8008, Reward: -536.30, Score:    0, Epsilon: 0.018
# Episode 8009, Reward: -585.80, Score:    0, Epsilon: 0.018
# Episode 8010, Reward: -433.63, Score:   92, Epsilon: 0.018
# Episode 8011, Reward: -522.30, Score:    0, Epsilon: 0.018
# Episode 8012, Reward: -364.39, Score:   68, Epsilon: 0.018
# Episode 8013, Reward: -497.51, Score:   34, Epsilon: 0.018
# Episode 8014, Reward: -492.80, Score:    0, Epsilon: 0.018
# Episode 8015, Reward: -471.86, Score:   42, Epsilon: 0.018
# Episode 8016, Reward: -490.50, Score:    0, Epsilon: 0.018
# Episode 8017, Reward: -262.05, Score:   42, Epsilon: 0.018
# Episode 8018, Reward: -560.80, Score:    0, Epsilon: 0.018
# Episode 8019, Reward: -346.11, Score:  102, Epsilon: 0.018
# Episode 8020, Reward: -523.80, Score:    0, Epsilon: 0.018
# Checkpoint saved at episode 8020, best score: 5848.00
# Loaded checkpoint from episode 8020, best score: 5848.00, epsilon=0.018
# Episode 8021, Reward: -504.51, Score:   82, Epsilon: 0.018
# Episode 8022, Reward: -305.10, Score:   50, Epsilon: 0.018
# Episode 8023, Reward: -423.90, Score:    0, Epsilon: 0.018
# Episode 8024, Reward: -169.64, Score:  134, Epsilon: 0.018
# Episode 8025, Reward: -320.47, Score:   80, Epsilon: 0.018
# Episode 8026, Reward: -378.20, Score:    0, Epsilon: 0.018
# Episode 8027, Reward: -470.55, Score:   50, Epsilon: 0.018
# Episode 8028, Reward: -310.11, Score:   42, Epsilon: 0.018
# Episode 8029, Reward: -505.50, Score:    0, Epsilon: 0.018
# Episode 8030, Reward: -397.55, Score:   50, Epsilon: 0.018
# Episode 8031, Reward: -306.80, Score:    0, Epsilon: 0.018
# Episode 8032, Reward: -440.50, Score:   10, Epsilon: 0.018
# Episode 8033, Reward: -520.20, Score:    0, Epsilon: 0.018
# Episode 8034, Reward: -514.30, Score:    0, Epsilon: 0.018
# Episode 8035, Reward: -530.60, Score:    0, Epsilon: 0.018
# Episode 8036, Reward: -312.21, Score:   68, Epsilon: 0.018
# Episode 8037, Reward: -441.00, Score:    0, Epsilon: 0.018
# Episode 8038, Reward: -163.10, Score:   78, Epsilon: 0.018
# Episode 8039, Reward: -286.52, Score:   68, Epsilon: 0.018
# Episode 8040, Reward: -416.37, Score:   18, Epsilon: 0.018
# Checkpoint saved at episode 8040, best score: 5848.00
# Loaded checkpoint from episode 8040, best score: 5848.00, epsilon=0.018
# Episode 8041, Reward:  -46.01, Score:  304, Epsilon: 0.018
# Episode 8042, Reward: -318.00, Score:   60, Epsilon: 0.018
# Episode 8043, Reward: -536.80, Score:   10, Epsilon: 0.018
# Episode 8044, Reward: -541.80, Score:    0, Epsilon: 0.018
# Episode 8045, Reward: -310.80, Score:   50, Epsilon: 0.018
# Episode 8046, Reward: -428.80, Score:   50, Epsilon: 0.018
# Episode 8047, Reward: -383.30, Score:    0, Epsilon: 0.018
# Episode 8048, Reward: -414.38, Score:   18, Epsilon: 0.018
# Episode 8049, Reward: -555.30, Score:    0, Epsilon: 0.018
# Episode 8050, Reward: -541.30, Score:    0, Epsilon: 0.018
# Episode 8051, Reward: -525.80, Score:    0, Epsilon: 0.018
# Episode 8052, Reward: -448.30, Score:    0, Epsilon: 0.018
# Episode 8053, Reward: -342.85, Score:   10, Epsilon: 0.018
# Episode 8054, Reward: -573.30, Score:    0, Epsilon: 0.018
# Episode 8055, Reward: -585.30, Score:    0, Epsilon: 0.018
# Episode 8056, Reward: -323.38, Score:   42, Epsilon: 0.018
# Episode 8057, Reward: -585.30, Score:    0, Epsilon: 0.018
# Episode 8058, Reward: -214.08, Score:   58, Epsilon: 0.018
# Episode 8059, Reward: -503.80, Score:    0, Epsilon: 0.018
# Episode 8060, Reward: -549.30, Score:    0, Epsilon: 0.018
# Checkpoint saved at episode 8060, best score: 5848.00
# Loaded checkpoint from episode 8060, best score: 5848.00, epsilon=0.018
# Episode 8061, Reward: -410.00, Score:  168, Epsilon: 0.018
# Episode 8062, Reward: -485.91, Score:   58, Epsilon: 0.018
# Episode 8063, Reward: -543.50, Score:   10, Epsilon: 0.018
# Episode 8064, Reward: -432.26, Score:   16, Epsilon: 0.018
# Episode 8065, Reward: -539.80, Score:    0, Epsilon: 0.018
# Episode 8066, Reward: -279.05, Score:   50, Epsilon: 0.018
# Episode 8067, Reward: -346.93, Score:   70, Epsilon: 0.018
# Episode 8068, Reward: -348.45, Score:   86, Epsilon: 0.018
# Episode 8069, Reward: -432.50, Score:   58, Epsilon: 0.018
# Episode 8070, Reward: -572.50, Score:    0, Epsilon: 0.018
# Episode 8071, Reward: -423.79, Score:   18, Epsilon: 0.018
# Episode 8072, Reward: -480.30, Score:    0, Epsilon: 0.018
# Episode 8073, Reward: -444.30, Score:    0, Epsilon: 0.018
# Episode 8074, Reward: -411.76, Score:   92, Epsilon: 0.018
# Episode 8075, Reward: -530.80, Score:    0, Epsilon: 0.018
# Episode 8076, Reward: -331.09, Score:  106, Epsilon: 0.018
# Episode 8077, Reward: -441.30, Score:    0, Epsilon: 0.018
# Episode 8078, Reward: -445.37, Score:   46, Epsilon: 0.018
# Episode 8079, Reward: -586.00, Score:    0, Epsilon: 0.018
# Episode 8080, Reward: -505.00, Score:    0, Epsilon: 0.018
# Checkpoint saved at episode 8080, best score: 5848.00
# Loaded checkpoint from episode 8080, best score: 5848.00, epsilon=0.018
# Episode 8081, Reward: -352.24, Score:  256, Epsilon: 0.018
# Episode 8082, Reward: -541.30, Score:    0, Epsilon: 0.018
# Episode 8083, Reward: -432.22, Score:   16, Epsilon: 0.018
# Episode 8084, Reward: -520.80, Score:    0, Epsilon: 0.018
# Episode 8085, Reward: -446.93, Score:   42, Epsilon: 0.018
# Episode 8086, Reward: -515.88, Score:   16, Epsilon: 0.018
# Episode 8087, Reward: -551.80, Score:    0, Epsilon: 0.018
# Episode 8088, Reward: -500.10, Score:    0, Epsilon: 0.018
# Episode 8089, Reward: -312.26, Score:   60, Epsilon: 0.018
# Episode 8090, Reward: -438.15, Score:   60, Epsilon: 0.017
# Episode 8091, Reward: -506.90, Score:   10, Epsilon: 0.017
# Episode 8092, Reward: -481.16, Score:   18, Epsilon: 0.017
# Episode 8093, Reward: -564.30, Score:    0, Epsilon: 0.017
# Episode 8094, Reward: -376.05, Score:   50, Epsilon: 0.017
# Episode 8095, Reward: -362.30, Score:    0, Epsilon: 0.017
# Episode 8096, Reward: -412.76, Score:   42, Epsilon: 0.017
# Episode 8097, Reward: -492.40, Score:   16, Epsilon: 0.017
# Episode 8098, Reward: -411.30, Score:    0, Epsilon: 0.017
# Episode 8099, Reward: -353.60, Score:   60, Epsilon: 0.017
# Episode 8100, Reward: -518.30, Score:    0, Epsilon: 0.017
# Checkpoint saved at episode 8100, best score: 5848.00
# Loaded checkpoint from episode 8100, best score: 5848.00, epsilon=0.017
# Episode 8101, Reward: -275.91, Score:  286, Epsilon: 0.017
# Episode 8102, Reward: -278.84, Score:   84, Epsilon: 0.017
# Episode 8103, Reward: -528.80, Score:   60, Epsilon: 0.017
# Episode 8104, Reward: -344.45, Score:   50, Epsilon: 0.017
# Episode 8105, Reward: -569.20, Score:    0, Epsilon: 0.017
# Episode 8106, Reward: -387.09, Score:   18, Epsilon: 0.017
# Episode 8107, Reward: -420.55, Score:   28, Epsilon: 0.017
# Episode 8108, Reward: -238.89, Score:   68, Epsilon: 0.017
# Episode 8109, Reward: -475.82, Score:   18, Epsilon: 0.017
# Episode 8110, Reward: -567.60, Score:    0, Epsilon: 0.017
# Episode 8111, Reward: -208.25, Score:  134, Epsilon: 0.017
# Episode 8112, Reward: -481.20, Score:    0, Epsilon: 0.017
# Episode 8113, Reward: -622.30, Score:    0, Epsilon: 0.017
# Episode 8114, Reward: -466.43, Score:   28, Epsilon: 0.017
# Episode 8115, Reward: -525.90, Score:    0, Epsilon: 0.017
# Episode 8116, Reward: -537.70, Score:    0, Epsilon: 0.017
# Episode 8117, Reward: -357.80, Score:   52, Epsilon: 0.017
# Episode 8118, Reward: -450.60, Score:    0, Epsilon: 0.017
# Episode 8119, Reward: -213.04, Score:  144, Epsilon: 0.017
# Episode 8120, Reward: -439.70, Score:    0, Epsilon: 0.017
# Checkpoint saved at episode 8120, best score: 5848.00
# Loaded checkpoint from episode 8120, best score: 5848.00, epsilon=0.017
# Episode 8121, Reward: -600.03, Score:  114, Epsilon: 0.017
# Episode 8122, Reward: -577.30, Score:    0, Epsilon: 0.017
# Episode 8123, Reward: -520.80, Score:    0, Epsilon: 0.017
# Episode 8124, Reward: -463.64, Score:   16, Epsilon: 0.017
# Episode 8125, Reward: -485.74, Score:   34, Epsilon: 0.017
# Episode 8126, Reward: -528.78, Score:   16, Epsilon: 0.017
# Episode 8127, Reward: -576.30, Score:    0, Epsilon: 0.017
# Episode 8128, Reward: -373.91, Score:   60, Epsilon: 0.017
# Episode 8129, Reward: -497.62, Score:   42, Epsilon: 0.017
# Episode 8130, Reward: -391.30, Score:  100, Epsilon: 0.017
# Episode 8131, Reward: -600.80, Score:    0, Epsilon: 0.017
# Episode 8132, Reward: -547.80, Score:    0, Epsilon: 0.017
# Episode 8133, Reward: -462.04, Score:   42, Epsilon: 0.017
# Episode 8134, Reward: -505.55, Score:   10, Epsilon: 0.017
# Episode 8135, Reward: -431.97, Score:   42, Epsilon: 0.017
# Episode 8136, Reward: -572.80, Score:    0, Epsilon: 0.017
# Episode 8137, Reward: -530.80, Score:    0, Epsilon: 0.017
# Episode 8138, Reward: -637.30, Score:    0, Epsilon: 0.017
# Episode 8139, Reward: -597.80, Score:    0, Epsilon: 0.017
# Episode 8140, Reward: -404.73, Score:   52, Epsilon: 0.017
# Checkpoint saved at episode 8140, best score: 5848.00
# Loaded checkpoint from episode 8140, best score: 5848.00, epsilon=0.017
# Episode 8141, Reward: -494.67, Score:  294, Epsilon: 0.017
# Episode 8142, Reward: -477.30, Score:    0, Epsilon: 0.017
# Episode 8143, Reward: -423.81, Score:   18, Epsilon: 0.017
# Episode 8144, Reward: -607.30, Score:    0, Epsilon: 0.017
# Episode 8145, Reward: -463.32, Score:   34, Epsilon: 0.017
# Episode 8146, Reward: -282.90, Score:   68, Epsilon: 0.017
# Episode 8147, Reward: -407.75, Score:   42, Epsilon: 0.017
# Episode 8148, Reward: -551.30, Score:    0, Epsilon: 0.017
# Episode 8149, Reward: -559.85, Score:   10, Epsilon: 0.017
# Episode 8150, Reward: -541.30, Score:    0, Epsilon: 0.017
# Episode 8151, Reward: -481.77, Score:   68, Epsilon: 0.017
# Episode 8152, Reward: -534.80, Score:    0, Epsilon: 0.017
# Episode 8153, Reward: -519.80, Score:    0, Epsilon: 0.017
# Episode 8154, Reward: -537.30, Score:    0, Epsilon: 0.017
# Episode 8155, Reward: -176.88, Score:  118, Epsilon: 0.017
# Episode 8156, Reward: -426.03, Score:   42, Epsilon: 0.017
# Episode 8157, Reward: -527.60, Score:    0, Epsilon: 0.017
# Episode 8158, Reward: -443.14, Score:   42, Epsilon: 0.017
# Episode 8159, Reward: -471.92, Score:   16, Epsilon: 0.017
# Episode 8160, Reward: -424.99, Score:   42, Epsilon: 0.017
# Checkpoint saved at episode 8160, best score: 5848.00
# Loaded checkpoint from episode 8160, best score: 5848.00, epsilon=0.017
# Episode 8161, Reward: -342.10, Score:  142, Epsilon: 0.017
# Episode 8162, Reward: -394.03, Score:   42, Epsilon: 0.017
# Episode 8163, Reward: -585.80, Score:    0, Epsilon: 0.017
# Episode 8164, Reward: -519.30, Score:    0, Epsilon: 0.017
# Episode 8165, Reward: -369.58, Score:   92, Epsilon: 0.017
# Episode 8166, Reward: -508.80, Score:    0, Epsilon: 0.017
# Episode 8167, Reward: -574.30, Score:    0, Epsilon: 0.017
# Episode 8168, Reward: -576.80, Score:    0, Epsilon: 0.017
# Episode 8169, Reward: -480.18, Score:   34, Epsilon: 0.017
# Episode 8170, Reward: -402.46, Score:   42, Epsilon: 0.017
# Episode 8171, Reward: -392.48, Score:   42, Epsilon: 0.017
# Episode 8172, Reward: -449.30, Score:    0, Epsilon: 0.017
# Episode 8173, Reward: -549.65, Score:   10, Epsilon: 0.017
# Episode 8174, Reward: -364.80, Score:  170, Epsilon: 0.017
# Episode 8175, Reward: -384.72, Score:  152, Epsilon: 0.017
# Episode 8176, Reward: -423.81, Score:  354, Epsilon: 0.017
# Episode 8177, Reward:  934.71, Score:  802, Epsilon: 0.017
# Episode 8178, Reward: -164.72, Score:  380, Epsilon: 0.017
# Episode 8179, Reward: -414.07, Score:  176, Epsilon: 0.017
# Episode 8180, Reward: -410.92, Score:  192, Epsilon: 0.017
# Checkpoint saved at episode 8180, best score: 5848.00
# Loaded checkpoint from episode 8180, best score: 5848.00, epsilon=0.017
# Episode 8181, Reward: -474.43, Score:  150, Epsilon: 0.017
# Episode 8182, Reward: -578.37, Score:  198, Epsilon: 0.017
# Episode 8183, Reward: -526.83, Score:  362, Epsilon: 0.017
# Episode 8184, Reward: -948.58, Score:  146, Epsilon: 0.017
# Episode 8185, Reward: -224.35, Score:  366, Epsilon: 0.017
# Episode 8186, Reward: -606.29, Score:   60, Epsilon: 0.017
# Episode 8187, Reward: -529.54, Score:  452, Epsilon: 0.017
# Episode 8188, Reward: -596.40, Score:  270, Epsilon: 0.017
# Episode 8189, Reward:  941.99, Score:  890, Epsilon: 0.017
# Episode 8190, Reward: -235.26, Score:  450, Epsilon: 0.017
# Episode 8191, Reward:  430.96, Score:  822, Epsilon: 0.017
# Episode 8192, Reward: -531.18, Score:  268, Epsilon: 0.017
# Episode 8193, Reward: 1005.88, Score:  894, Epsilon: 0.017
# Episode 8194, Reward: -769.10, Score:   68, Epsilon: 0.017
# Episode 8195, Reward: -725.99, Score:  136, Epsilon: 0.017
# Episode 8196, Reward:  -70.27, Score:  576, Epsilon: 0.017
# Episode 8197, Reward: -546.74, Score:  266, Epsilon: 0.017
# Episode 8198, Reward: -341.86, Score:  420, Epsilon: 0.017
# Episode 8199, Reward: -785.38, Score:  224, Epsilon: 0.017
# Episode 8200, Reward: -571.01, Score:  172, Epsilon: 0.017
# Checkpoint saved at episode 8200, best score: 5848.00
# Loaded checkpoint from episode 8200, best score: 5848.00, epsilon=0.017
# Episode 8201, Reward:  -46.47, Score:  328, Epsilon: 0.017
# Episode 8202, Reward: -451.99, Score:   58, Epsilon: 0.017
# Episode 8203, Reward: -209.69, Score:  126, Epsilon: 0.017
# Episode 8204, Reward: -402.87, Score:   60, Epsilon: 0.017
# Episode 8205, Reward: -436.80, Score:    0, Epsilon: 0.017
# Episode 8206, Reward: -440.59, Score:   18, Epsilon: 0.017
# Episode 8207, Reward: -564.80, Score:    0, Epsilon: 0.016
# Episode 8208, Reward: -494.55, Score:   18, Epsilon: 0.016
# Episode 8209, Reward: -214.80, Score:  118, Epsilon: 0.016
# Episode 8210, Reward: -474.48, Score:   52, Epsilon: 0.016
# Episode 8211, Reward: -401.67, Score:   18, Epsilon: 0.016
# Episode 8212, Reward: -479.26, Score:   42, Epsilon: 0.016
# Episode 8213, Reward: -453.49, Score:   92, Epsilon: 0.016
# Episode 8214, Reward: -538.13, Score:   18, Epsilon: 0.016
# Episode 8215, Reward: -476.85, Score:   18, Epsilon: 0.016
# Episode 8216, Reward: -510.10, Score:    0, Epsilon: 0.016
# Episode 8217, Reward: -513.46, Score:   68, Epsilon: 0.016
# Episode 8218, Reward: -498.60, Score:    0, Epsilon: 0.016
# Episode 8219, Reward: -561.00, Score:    0, Epsilon: 0.016
# Episode 8220, Reward: -387.47, Score:   84, Epsilon: 0.016
# Checkpoint saved at episode 8220, best score: 5848.00
# Loaded checkpoint from episode 8220, best score: 5848.00, epsilon=0.016
# Episode 8221, Reward: -463.62, Score:  150, Epsilon: 0.016
# Episode 8222, Reward: -484.80, Score:    0, Epsilon: 0.016
# Episode 8223, Reward: -449.80, Score:    0, Epsilon: 0.016
# Episode 8224, Reward: -565.80, Score:    0, Epsilon: 0.016
# Episode 8225, Reward: -506.00, Score:    0, Epsilon: 0.016
# Episode 8226, Reward: -383.80, Score:    0, Epsilon: 0.016
# Episode 8227, Reward: -512.30, Score:    0, Epsilon: 0.016
# Episode 8228, Reward: -457.30, Score:    0, Epsilon: 0.016
# Episode 8229, Reward: -528.80, Score:    0, Epsilon: 0.016
# Episode 8230, Reward: -386.06, Score:   42, Epsilon: 0.016
# Episode 8231, Reward: -397.90, Score:   20, Epsilon: 0.016
# Episode 8232, Reward: -311.35, Score:   58, Epsilon: 0.016
# Episode 8233, Reward: -584.60, Score:    0, Epsilon: 0.016
# Episode 8234, Reward: -460.38, Score:   16, Epsilon: 0.016
# Episode 8235, Reward: -400.25, Score:   50, Epsilon: 0.016
# Episode 8236, Reward: -448.70, Score:    0, Epsilon: 0.016
# Episode 8237, Reward: -519.00, Score:    0, Epsilon: 0.016
# Episode 8238, Reward: -522.10, Score:    0, Epsilon: 0.016
# Episode 8239, Reward: -571.80, Score:    0, Epsilon: 0.016
# Episode 8240, Reward: -381.30, Score:   50, Epsilon: 0.016
# Checkpoint saved at episode 8240, best score: 5848.00
# Loaded checkpoint from episode 8240, best score: 5848.00, epsilon=0.016
# Episode 8241, Reward: -178.00, Score:  188, Epsilon: 0.016
# Episode 8242, Reward: -426.42, Score:   18, Epsilon: 0.016
# Episode 8243, Reward: -456.90, Score:   42, Epsilon: 0.016
# Episode 8244, Reward: -432.65, Score:   42, Epsilon: 0.016
# Episode 8245, Reward: -278.80, Score:  100, Epsilon: 0.016
# Episode 8246, Reward: -492.45, Score:   18, Epsilon: 0.016
# Episode 8247, Reward: -461.02, Score:   32, Epsilon: 0.016
# Episode 8248, Reward: -412.25, Score:   10, Epsilon: 0.016
# Episode 8249, Reward: -458.78, Score:   18, Epsilon: 0.016
# Episode 8250, Reward: -588.80, Score:    0, Epsilon: 0.016
# Episode 8251, Reward: -511.56, Score:   18, Epsilon: 0.016
# Episode 8252, Reward: -432.39, Score:   68, Epsilon: 0.016
# Episode 8253, Reward: -439.80, Score:    0, Epsilon: 0.016
# Episode 8254, Reward: -403.44, Score:   58, Epsilon: 0.016
# Episode 8255, Reward: -518.60, Score:   18, Epsilon: 0.016
# Episode 8256, Reward: -483.80, Score:    0, Epsilon: 0.016
# Episode 8257, Reward: -364.67, Score:   84, Epsilon: 0.016
# Episode 8258, Reward: -306.30, Score:    0, Epsilon: 0.016
# Episode 8259, Reward: -574.39, Score:   34, Epsilon: 0.016
# Episode 8260, Reward: -513.55, Score:   50, Epsilon: 0.016
# Checkpoint saved at episode 8260, best score: 5848.00
# Loaded checkpoint from episode 8260, best score: 5848.00, epsilon=0.016
# Episode 8261, Reward: -398.32, Score:   52, Epsilon: 0.016
# Episode 8262, Reward: -434.91, Score:   42, Epsilon: 0.016
# Episode 8263, Reward: -406.50, Score:   50, Epsilon: 0.016
# Episode 8264, Reward: -482.78, Score:   16, Epsilon: 0.016
# Episode 8265, Reward: -420.80, Score:   18, Epsilon: 0.016
# Episode 8266, Reward: -546.21, Score:   42, Epsilon: 0.016
# Episode 8267, Reward: -549.28, Score:   16, Epsilon: 0.016
# Episode 8268, Reward: -526.30, Score:    0, Epsilon: 0.016
# Episode 8269, Reward: -720.58, Score:  192, Epsilon: 0.016
# Episode 8270, Reward: -332.50, Score:  388, Epsilon: 0.016
# Episode 8271, Reward: 1491.62, Score:  672, Epsilon: 0.016
# Episode 8272, Reward:  -28.04, Score:  430, Epsilon: 0.016
# Episode 8273, Reward:  192.95, Score:  566, Epsilon: 0.016
# Episode 8274, Reward:  800.40, Score:  472, Epsilon: 0.016
# Episode 8275, Reward: -103.99, Score:  294, Epsilon: 0.016
# Episode 8276, Reward: -367.76, Score:  274, Epsilon: 0.016
# Episode 8277, Reward:   60.21, Score:  396, Epsilon: 0.016
# Episode 8278, Reward: -337.10, Score:  198, Epsilon: 0.016
# Episode 8279, Reward: -133.33, Score:  294, Epsilon: 0.016
# Episode 8280, Reward: -641.59, Score:   88, Epsilon: 0.016
# Checkpoint saved at episode 8280, best score: 5848.00
# Loaded checkpoint from episode 8280, best score: 5848.00, epsilon=0.016
# Episode 8281, Reward: -530.10, Score:   58, Epsilon: 0.016
# Episode 8282, Reward: -579.80, Score:    0, Epsilon: 0.016
# Episode 8283, Reward: -349.75, Score:   42, Epsilon: 0.016
# Episode 8284, Reward: -525.20, Score:    0, Epsilon: 0.016
# Episode 8285, Reward: -466.80, Score:    0, Epsilon: 0.016
# Episode 8286, Reward: -566.50, Score:    0, Epsilon: 0.016
# Episode 8287, Reward: -580.20, Score:    0, Epsilon: 0.016
# Episode 8288, Reward: -548.80, Score:    0, Epsilon: 0.016
# Episode 8289, Reward: -550.90, Score:    0, Epsilon: 0.016
# Episode 8290, Reward: -370.60, Score:   50, Epsilon: 0.016
# Episode 8291, Reward: -324.88, Score:  262, Epsilon: 0.016
# Episode 8292, Reward: -397.79, Score:  230, Epsilon: 0.016
# Episode 8293, Reward: -585.00, Score:   50, Epsilon: 0.016
# Episode 8294, Reward: -417.82, Score:  150, Epsilon: 0.016
# Episode 8295, Reward: -550.20, Score:   76, Epsilon: 0.016
# Episode 8296, Reward:  -66.79, Score:  344, Epsilon: 0.016
# Episode 8297, Reward: -308.19, Score:  192, Epsilon: 0.016
# Episode 8298, Reward: -610.39, Score:   58, Epsilon: 0.016
# Episode 8299, Reward: -172.68, Score:  356, Epsilon: 0.016
# Episode 8300, Reward: -286.29, Score:  258, Epsilon: 0.016
# Checkpoint saved at episode 8300, best score: 5848.00
# Loaded checkpoint from episode 8300, best score: 5848.00, epsilon=0.016
# Episode 8301, Reward: -347.59, Score:  102, Epsilon: 0.016
# Episode 8302, Reward: -403.80, Score:   50, Epsilon: 0.016
# Episode 8303, Reward: -520.65, Score:   10, Epsilon: 0.016
# Episode 8304, Reward: -439.01, Score:   34, Epsilon: 0.016
# Episode 8305, Reward: -412.24, Score:   42, Epsilon: 0.016
# Episode 8306, Reward: -550.30, Score:    0, Epsilon: 0.016
# Episode 8307, Reward: -487.30, Score:    0, Epsilon: 0.016
# Episode 8308, Reward: -504.41, Score:   42, Epsilon: 0.016
# Episode 8309, Reward: -404.80, Score:    0, Epsilon: 0.016
# Episode 8310, Reward: -405.30, Score:   50, Epsilon: 0.016
# Episode 8311, Reward:  783.53, Score:  912, Epsilon: 0.016
# Episode 8312, Reward: -472.00, Score:  238, Epsilon: 0.016
# Episode 8313, Reward:  677.88, Score:  616, Epsilon: 0.016
# Episode 8314, Reward: -678.99, Score:  150, Epsilon: 0.016
# Episode 8315, Reward: -477.21, Score:  214, Epsilon: 0.016
# Episode 8316, Reward: -138.25, Score:  422, Epsilon: 0.016
# Episode 8317, Reward: -765.29, Score:  180, Epsilon: 0.016
# Episode 8318, Reward:   18.18, Score:  406, Epsilon: 0.016
# Episode 8319, Reward: -326.47, Score:  278, Epsilon: 0.016
# Episode 8320, Reward: -711.36, Score:   94, Epsilon: 0.016
# Checkpoint saved at episode 8320, best score: 5848.00
# Loaded checkpoint from episode 8320, best score: 5848.00, epsilon=0.016
# Episode 8321, Reward: -474.53, Score:  166, Epsilon: 0.016
# Episode 8322, Reward:  496.90, Score:  964, Epsilon: 0.016
# Episode 8323, Reward: 4343.10, Score: 1864, Epsilon: 0.016
# Episode 8324, Reward: -713.08, Score:  410, Epsilon: 0.016
# Episode 8325, Reward: -735.13, Score:   96, Epsilon: 0.016
# Episode 8326, Reward: 3045.00, Score: 1414, Epsilon: 0.016
# Episode 8327, Reward: -634.61, Score:  158, Epsilon: 0.016
# Episode 8328, Reward: -404.16, Score:  296, Epsilon: 0.016
# Episode 8329, Reward:   48.73, Score:  550, Epsilon: 0.016
# Episode 8330, Reward: -281.08, Score:  288, Epsilon: 0.016
# Episode 8331, Reward:   -1.31, Score:  422, Epsilon: 0.016
# Episode 8332, Reward:  932.28, Score:  750, Epsilon: 0.015
# Episode 8333, Reward: -461.86, Score:  152, Epsilon: 0.015
# Episode 8334, Reward: -460.37, Score:  248, Epsilon: 0.015
# Episode 8335, Reward: -535.78, Score:  226, Epsilon: 0.015
# Episode 8336, Reward: -537.15, Score:  214, Epsilon: 0.015
# Episode 8337, Reward: -393.08, Score:  362, Epsilon: 0.015
# Episode 8338, Reward: -382.73, Score:  354, Epsilon: 0.015
# Episode 8339, Reward:   -9.17, Score:  532, Epsilon: 0.015
# Episode 8340, Reward:  470.42, Score:  628, Epsilon: 0.015
# Checkpoint saved at episode 8340, best score: 5848.00
# Loaded checkpoint from episode 8340, best score: 5848.00, epsilon=0.015
# Episode 8341, Reward:   85.08, Score:  576, Epsilon: 0.015
# Episode 8342, Reward: -455.92, Score:  608, Epsilon: 0.015
# Episode 8343, Reward: 2051.75, Score: 1318, Epsilon: 0.015
# Episode 8344, Reward:  734.63, Score: 1056, Epsilon: 0.015
# Episode 8345, Reward:  133.42, Score:  800, Epsilon: 0.015
# Episode 8346, Reward:  -23.99, Score:  792, Epsilon: 0.015
# Episode 8347, Reward: -631.37, Score:  418, Epsilon: 0.015
# Episode 8348, Reward: -728.43, Score:  408, Epsilon: 0.015
# Episode 8349, Reward: 4215.38, Score: 1516, Epsilon: 0.015
# Episode 8350, Reward:  677.95, Score:  692, Epsilon: 0.015
# Episode 8351, Reward: -750.14, Score:   92, Epsilon: 0.015
# Episode 8352, Reward: -328.46, Score:  338, Epsilon: 0.015
# Episode 8353, Reward: 1166.74, Score:  572, Epsilon: 0.015
# Episode 8354, Reward: -357.51, Score:  234, Epsilon: 0.015
# Episode 8355, Reward: -212.52, Score:  264, Epsilon: 0.015
# Episode 8356, Reward:   21.61, Score:  320, Epsilon: 0.015
# Episode 8357, Reward: -486.77, Score:  180, Epsilon: 0.015
# Episode 8358, Reward: -498.43, Score:  194, Epsilon: 0.015
# Episode 8359, Reward: -154.15, Score:  310, Epsilon: 0.015
# Episode 8360, Reward:  397.68, Score:  508, Epsilon: 0.015
# Checkpoint saved at episode 8360, best score: 5848.00
# Loaded checkpoint from episode 8360, best score: 5848.00, epsilon=0.015
# Episode 8361, Reward: -442.76, Score:  192, Epsilon: 0.015
# Episode 8362, Reward: -469.75, Score:   50, Epsilon: 0.015
# Episode 8363, Reward: -328.69, Score:  110, Epsilon: 0.015
# Episode 8364, Reward: -456.60, Score:    0, Epsilon: 0.015
# Episode 8365, Reward: -488.70, Score:    0, Epsilon: 0.015
# Episode 8366, Reward: -495.20, Score:    0, Epsilon: 0.015
# Episode 8367, Reward: -393.60, Score:    0, Epsilon: 0.015
# Episode 8368, Reward: -470.44, Score:   66, Epsilon: 0.015
# Episode 8369, Reward: -237.69, Score:   84, Epsilon: 0.015
# Episode 8370, Reward: -403.05, Score:   10, Epsilon: 0.015
# Episode 8371, Reward: -520.30, Score:    0, Epsilon: 0.015
# Episode 8372, Reward: -486.50, Score:    0, Epsilon: 0.015
# Episode 8373, Reward: -403.30, Score:    0, Epsilon: 0.015
# Episode 8374, Reward: -400.70, Score:   16, Epsilon: 0.015
# Episode 8375, Reward: -410.24, Score:   60, Epsilon: 0.015
# Episode 8376, Reward: -380.92, Score:   76, Epsilon: 0.015
# Episode 8377, Reward: -413.30, Score:   50, Epsilon: 0.015
# Episode 8378, Reward: -130.10, Score:  100, Epsilon: 0.015
# Episode 8379, Reward: -564.80, Score:    0, Epsilon: 0.015
# Episode 8380, Reward: -539.80, Score:    0, Epsilon: 0.015
# Checkpoint saved at episode 8380, best score: 5848.00
# Loaded checkpoint from episode 8380, best score: 5848.00, epsilon=0.015
# Episode 8381, Reward: -489.27, Score:  214, Epsilon: 0.015
# Episode 8382, Reward: -430.78, Score:   18, Epsilon: 0.015
# Episode 8383, Reward: -555.55, Score:   10, Epsilon: 0.015
# Episode 8384, Reward: -580.50, Score:    0, Epsilon: 0.015
# Episode 8385, Reward: -539.80, Score:    0, Epsilon: 0.015
# Episode 8386, Reward: -153.22, Score:  102, Epsilon: 0.015
# Episode 8387, Reward: -500.47, Score:   42, Epsilon: 0.015
# Episode 8388, Reward: -413.54, Score:   28, Epsilon: 0.015
# Episode 8389, Reward: -442.30, Score:   50, Epsilon: 0.015
# Episode 8390, Reward: -384.00, Score:   50, Epsilon: 0.015
# Episode 8391, Reward: -543.00, Score:   10, Epsilon: 0.015
# Episode 8392, Reward: -561.61, Score:  320, Epsilon: 0.015
# Episode 8393, Reward: -366.58, Score:  276, Epsilon: 0.015
# Episode 8394, Reward: -549.19, Score:  272, Epsilon: 0.015
# Episode 8395, Reward: -222.99, Score:  388, Epsilon: 0.015
# Episode 8396, Reward: -676.37, Score:   42, Epsilon: 0.015
# Episode 8397, Reward: -242.35, Score:  428, Epsilon: 0.015
# Episode 8398, Reward: -625.57, Score:  128, Epsilon: 0.015
# Episode 8399, Reward: -422.77, Score:  184, Epsilon: 0.015
# Episode 8400, Reward: -688.07, Score:  104, Epsilon: 0.015
# Checkpoint saved at episode 8400, best score: 5848.00
# Loaded checkpoint from episode 8400, best score: 5848.00, epsilon=0.015
# Episode 8401, Reward: 1945.60, Score:  972, Epsilon: 0.015
# Episode 8402, Reward: 3731.36, Score: 1516, Epsilon: 0.015
# Episode 8403, Reward:  186.81, Score:  890, Epsilon: 0.015
# Episode 8404, Reward: -694.95, Score:  204, Epsilon: 0.015
# Episode 8405, Reward:  441.38, Score:  948, Epsilon: 0.015
# Episode 8406, Reward: 6771.31, Score: 1620, Epsilon: 0.015
# Episode 8407, Reward: -511.51, Score:  146, Epsilon: 0.015
# Episode 8408, Reward:  -81.67, Score:  312, Epsilon: 0.015
# Episode 8409, Reward: 1842.97, Score:  832, Epsilon: 0.015
# Episode 8410, Reward: -459.74, Score:  206, Epsilon: 0.015
# Episode 8411, Reward: -611.74, Score:  120, Epsilon: 0.015
# Episode 8412, Reward: -608.45, Score:  156, Epsilon: 0.015
# Episode 8413, Reward: -173.81, Score:  350, Epsilon: 0.015
# Episode 8414, Reward: -223.95, Score:  350, Epsilon: 0.015
# Episode 8415, Reward:   51.86, Score:  472, Epsilon: 0.015
# Episode 8416, Reward: -479.32, Score:  190, Epsilon: 0.015
# Episode 8417, Reward:  -62.99, Score:  440, Epsilon: 0.015
# Episode 8418, Reward: -249.61, Score:  324, Epsilon: 0.015
# Episode 8419, Reward:   11.77, Score:  428, Epsilon: 0.015
# Episode 8420, Reward: -503.51, Score:  282, Epsilon: 0.015
# Checkpoint saved at episode 8420, best score: 5848.00
# Loaded checkpoint from episode 8420, best score: 5848.00, epsilon=0.015
# Episode 8421, Reward: -511.44, Score:  148, Epsilon: 0.015
# Episode 8422, Reward: -586.00, Score:    0, Epsilon: 0.015
# Episode 8423, Reward: -366.54, Score:   16, Epsilon: 0.015
# Episode 8424, Reward: -396.50, Score:    0, Epsilon: 0.015
# Episode 8425, Reward: -256.40, Score:    0, Epsilon: 0.015
# Episode 8426, Reward: -450.30, Score:    0, Epsilon: 0.015
# Episode 8427, Reward: -412.13, Score:   18, Epsilon: 0.015
# Episode 8428, Reward: -483.00, Score:    0, Epsilon: 0.015
# Episode 8429, Reward: -413.25, Score:   50, Epsilon: 0.015
# Episode 8430, Reward: -278.66, Score:   78, Epsilon: 0.015
# Episode 8431, Reward: -491.90, Score:   10, Epsilon: 0.015
# Episode 8432, Reward: -491.60, Score:    0, Epsilon: 0.015
# Episode 8433, Reward: -569.50, Score:    0, Epsilon: 0.015
# Episode 8434, Reward: -490.70, Score:   18, Epsilon: 0.015
# Episode 8435, Reward: -414.39, Score:  304, Epsilon: 0.015
# Episode 8436, Reward: -466.34, Score:  200, Epsilon: 0.015
# Episode 8437, Reward:  168.71, Score:  492, Epsilon: 0.015
# Episode 8438, Reward: -489.43, Score:  150, Epsilon: 0.015
# Episode 8439, Reward:  587.41, Score:  580, Epsilon: 0.015
# Episode 8440, Reward: -200.85, Score:  364, Epsilon: 0.015
# Checkpoint saved at episode 8440, best score: 5848.00
# Loaded checkpoint from episode 8440, best score: 5848.00, epsilon=0.015
# Episode 8441, Reward: -197.11, Score:  308, Epsilon: 0.015
# Episode 8442, Reward: -480.10, Score:    0, Epsilon: 0.015
# Episode 8443, Reward: -447.60, Score:    0, Epsilon: 0.015
# Episode 8444, Reward: -344.92, Score:   58, Epsilon: 0.015
# Episode 8445, Reward: -318.88, Score:   84, Epsilon: 0.015
# Episode 8446, Reward: -397.60, Score:    0, Epsilon: 0.015
# Episode 8447, Reward: -467.50, Score:    0, Epsilon: 0.015
# Episode 8448, Reward: -347.05, Score:   94, Epsilon: 0.015
# Episode 8449, Reward: -396.58, Score:  320, Epsilon: 0.015
# Episode 8450, Reward: -120.54, Score:  472, Epsilon: 0.015
# Episode 8451, Reward: -272.98, Score:  330, Epsilon: 0.015
# Episode 8452, Reward:   52.94, Score:  454, Epsilon: 0.015
# Episode 8453, Reward:  203.53, Score:  426, Epsilon: 0.015
# Episode 8454, Reward: -336.95, Score:  322, Epsilon: 0.015
# Episode 8455, Reward:   64.54, Score:  378, Epsilon: 0.015
# Episode 8456, Reward: -403.86, Score:  168, Epsilon: 0.015
# Episode 8457, Reward:    0.94, Score:  392, Epsilon: 0.015
# Episode 8458, Reward: -247.91, Score:  270, Epsilon: 0.015
# Episode 8459, Reward: -307.41, Score:  222, Epsilon: 0.015
# Episode 8460, Reward: -452.40, Score:  148, Epsilon: 0.015
# Checkpoint saved at episode 8460, best score: 5848.00
# Loaded checkpoint from episode 8460, best score: 5848.00, epsilon=0.015
# Episode 8461, Reward:  132.13, Score:  388, Epsilon: 0.015
# Episode 8462, Reward: -677.33, Score:  336, Epsilon: 0.015
# Episode 8463, Reward: -521.25, Score:  392, Epsilon: 0.015
# Episode 8464, Reward: -348.36, Score:  704, Epsilon: 0.015
# Episode 8465, Reward:   -9.70, Score:  730, Epsilon: 0.015
# Episode 8466, Reward: -707.77, Score:  520, Epsilon: 0.014
# Episode 8467, Reward:  469.03, Score:  744, Epsilon: 0.014
# Episode 8468, Reward: -672.36, Score:  182, Epsilon: 0.014
# Episode 8469, Reward:  779.43, Score:  910, Epsilon: 0.014
# Episode 8470, Reward: -573.04, Score:  220, Epsilon: 0.014
# Episode 8471, Reward: -608.46, Score:  166, Epsilon: 0.014
# Episode 8472, Reward: -388.82, Score:  204, Epsilon: 0.014
# Episode 8473, Reward: -484.89, Score:  118, Epsilon: 0.014
# Episode 8474, Reward: -332.88, Score:  304, Epsilon: 0.014
# Episode 8475, Reward:  -26.75, Score:  422, Epsilon: 0.014
# Episode 8476, Reward: -521.88, Score:  186, Epsilon: 0.014
# Episode 8477, Reward: -444.98, Score:  150, Epsilon: 0.014
# Episode 8478, Reward: 1213.06, Score:  670, Epsilon: 0.014
# Episode 8479, Reward: -315.44, Score:  256, Epsilon: 0.014
# Episode 8480, Reward:   94.01, Score:  418, Epsilon: 0.014
# Checkpoint saved at episode 8480, best score: 5848.00
# Loaded checkpoint from episode 8480, best score: 5848.00, epsilon=0.014
# Episode 8481, Reward: -217.16, Score:  254, Epsilon: 0.014
# Episode 8482, Reward: -499.29, Score:   58, Epsilon: 0.014
# Episode 8483, Reward: -463.93, Score:   82, Epsilon: 0.014
# Episode 8484, Reward: 2622.30, Score: 1088, Epsilon: 0.014
# Episode 8485, Reward: -131.78, Score:  400, Epsilon: 0.014
# Episode 8486, Reward:  927.23, Score:  796, Epsilon: 0.014
# Episode 8487, Reward:  204.64, Score:  538, Epsilon: 0.014
# Episode 8488, Reward:   41.66, Score:  510, Epsilon: 0.014
# Episode 8489, Reward: -510.86, Score:  120, Epsilon: 0.014
# Episode 8490, Reward: -555.34, Score:  112, Epsilon: 0.014
# Episode 8491, Reward: -271.46, Score:  292, Epsilon: 0.014
# Episode 8492, Reward: -641.37, Score:  138, Epsilon: 0.014
# Episode 8493, Reward: -556.83, Score:  102, Epsilon: 0.014
# Episode 8494, Reward: -500.72, Score:  230, Epsilon: 0.014
# Episode 8495, Reward: -584.90, Score:  142, Epsilon: 0.014
# Episode 8496, Reward: -396.92, Score:  322, Epsilon: 0.014
# Episode 8497, Reward: -278.39, Score:  340, Epsilon: 0.014
# Episode 8498, Reward:  125.27, Score:  426, Epsilon: 0.014
# Episode 8499, Reward: -100.84, Score:  424, Epsilon: 0.014
# Episode 8500, Reward: -607.02, Score:  142, Epsilon: 0.014
# Checkpoint saved at episode 8500, best score: 5848.00
# Loaded checkpoint from episode 8500, best score: 5848.00, epsilon=0.014
# Episode 8501, Reward: -216.85, Score:  296, Epsilon: 0.014
# Episode 8502, Reward:  -80.43, Score:   42, Epsilon: 0.014
# Episode 8503, Reward: -472.70, Score:   10, Epsilon: 0.014
# Episode 8504, Reward: -468.35, Score:   42, Epsilon: 0.014
# Episode 8505, Reward: -463.45, Score:   92, Epsilon: 0.014
# Episode 8506, Reward: -469.19, Score:   18, Epsilon: 0.014
# Episode 8507, Reward:  -11.87, Score:  474, Epsilon: 0.014
# Episode 8508, Reward: -371.17, Score:  208, Epsilon: 0.014
# Episode 8509, Reward: -411.83, Score:  170, Epsilon: 0.014
# Episode 8510, Reward:  432.16, Score:  516, Epsilon: 0.014
# Episode 8511, Reward: -555.41, Score:  158, Epsilon: 0.014
# Episode 8512, Reward: -489.07, Score:  206, Epsilon: 0.014
# Episode 8513, Reward: -296.51, Score:  196, Epsilon: 0.014
# Episode 8514, Reward: -229.14, Score:  262, Epsilon: 0.014
# Episode 8515, Reward: -198.87, Score:  426, Epsilon: 0.014
# Episode 8516, Reward:  592.61, Score:  526, Epsilon: 0.014
# Episode 8517, Reward: -125.82, Score:  270, Epsilon: 0.014
# Episode 8518, Reward: -313.08, Score:  280, Epsilon: 0.014
# Episode 8519, Reward:  -25.95, Score:  380, Epsilon: 0.014
# Episode 8520, Reward: -107.27, Score:  348, Epsilon: 0.014
# Checkpoint saved at episode 8520, best score: 5848.00
# Loaded checkpoint from episode 8520, best score: 5848.00, epsilon=0.014
# Episode 8521, Reward: -355.24, Score:  164, Epsilon: 0.014
# Episode 8522, Reward: -521.80, Score:    0, Epsilon: 0.014
# Episode 8523, Reward: -506.98, Score:   16, Epsilon: 0.014
# Episode 8524, Reward: -467.65, Score:   10, Epsilon: 0.014
# Episode 8525, Reward: -435.05, Score:   50, Epsilon: 0.014
# Episode 8526, Reward: -503.53, Score:   92, Epsilon: 0.014
# Episode 8527, Reward: -100.36, Score:  506, Epsilon: 0.014
# Episode 8528, Reward:  -89.09, Score:  638, Epsilon: 0.014
# Episode 8529, Reward: -318.23, Score:  328, Epsilon: 0.014
# Episode 8530, Reward: -468.56, Score:  136, Epsilon: 0.014
# Episode 8531, Reward: -222.84, Score:  388, Epsilon: 0.014
# Episode 8532, Reward: -229.46, Score:  250, Epsilon: 0.014
# Episode 8533, Reward:  526.61, Score:  602, Epsilon: 0.014
# Episode 8534, Reward: -502.21, Score:  244, Epsilon: 0.014
# Episode 8535, Reward: -200.79, Score:  254, Epsilon: 0.014
# Episode 8536, Reward: -194.56, Score:  340, Epsilon: 0.014
# Episode 8537, Reward: -444.97, Score:  188, Epsilon: 0.014
# Episode 8538, Reward: -131.27, Score:  364, Epsilon: 0.014
# Episode 8539, Reward: -601.47, Score:  102, Epsilon: 0.014
# Episode 8540, Reward: -238.50, Score:  234, Epsilon: 0.014
# Checkpoint saved at episode 8540, best score: 5848.00
# Loaded checkpoint from episode 8540, best score: 5848.00, epsilon=0.014
# Episode 8541, Reward: -556.38, Score:  108, Epsilon: 0.014
# Episode 8542, Reward: -633.41, Score:  436, Epsilon: 0.014
# Episode 8543, Reward: -723.34, Score:  218, Epsilon: 0.014
# Episode 8544, Reward: 2374.21, Score: 1204, Epsilon: 0.014
# Episode 8545, Reward: -388.80, Score:  328, Epsilon: 0.014
# Episode 8546, Reward: -450.96, Score:  178, Epsilon: 0.014
# Episode 8547, Reward:   90.54, Score:  478, Epsilon: 0.014
# Episode 8548, Reward: 1784.81, Score:  942, Epsilon: 0.014
# Episode 8549, Reward: 1126.95, Score:  750, Epsilon: 0.014
# Episode 8550, Reward: -435.94, Score:  184, Epsilon: 0.014
# Episode 8551, Reward:  124.13, Score:  574, Epsilon: 0.014
# Episode 8552, Reward: -631.63, Score:  136, Epsilon: 0.014
# Episode 8553, Reward: -295.66, Score:  280, Epsilon: 0.014
# Episode 8554, Reward:  555.96, Score:  620, Epsilon: 0.014
# Episode 8555, Reward: -174.51, Score:  406, Epsilon: 0.014
# Episode 8556, Reward: -368.01, Score:  280, Epsilon: 0.014
# Episode 8557, Reward:   59.79, Score:  450, Epsilon: 0.014
# Episode 8558, Reward: -110.59, Score:  394, Epsilon: 0.014
# Episode 8559, Reward: -266.32, Score:  354, Epsilon: 0.014
# Episode 8560, Reward: -411.53, Score:  296, Epsilon: 0.014
# Checkpoint saved at episode 8560, best score: 5848.00
# Loaded checkpoint from episode 8560, best score: 5848.00, epsilon=0.014
# Episode 8561, Reward:  -37.99, Score:  312, Epsilon: 0.014
# Episode 8562, Reward: -437.81, Score:   76, Epsilon: 0.014
# Episode 8563, Reward: -505.30, Score:   32, Epsilon: 0.014
# Episode 8564, Reward: -465.99, Score:   42, Epsilon: 0.014
# Episode 8565, Reward:  123.93, Score:  314, Epsilon: 0.014
# Episode 8566, Reward: -425.51, Score:  138, Epsilon: 0.014
# Episode 8567, Reward: -630.52, Score:   36, Epsilon: 0.014
# Episode 8568, Reward:  778.27, Score:  594, Epsilon: 0.014
# Episode 8569, Reward: -168.81, Score:  226, Epsilon: 0.014
# Episode 8570, Reward: -187.73, Score:  262, Epsilon: 0.014
# Episode 8571, Reward:  349.98, Score:  528, Epsilon: 0.014
# Episode 8572, Reward: -384.78, Score:  246, Epsilon: 0.014
# Episode 8573, Reward:  -30.38, Score:  370, Epsilon: 0.014
# Episode 8574, Reward: -512.75, Score:  166, Epsilon: 0.014
# Episode 8575, Reward: -688.62, Score:  126, Epsilon: 0.014
# Episode 8576, Reward:  255.65, Score:  542, Epsilon: 0.014
# Episode 8577, Reward: -403.69, Score:  232, Epsilon: 0.014
# Episode 8578, Reward: -345.36, Score:  232, Epsilon: 0.014
# Episode 8579, Reward:   95.62, Score:  520, Epsilon: 0.014
# Episode 8580, Reward: -372.18, Score:  240, Epsilon: 0.014
# ...
# Episode 8815, Reward: -300.29, Score:  266, Epsilon: 0.012
# Episode 8816, Reward:    3.91, Score:  452, Epsilon: 0.012
# Episode 8817, Reward: -665.34, Score:   76, Epsilon: 0.012
# Episode 8818, Reward:   35.58, Score:  462, Epsilon: 0.012
# Episode 8819, Reward: -633.46, Score:  196, Epsilon: 0.012
# Episode 8820, Reward:   -8.92, Score:  364, Epsilon: 0.012
# Checkpoint saved at episode 8820, best score: 5848.00
# Loaded checkpoint from episode 8820, best score: 5848.00, epsilon=0.012
# Episode 8821, Reward: -183.29, Score:  240, Epsilon: 0.012
# Episode 8822, Reward: -556.30, Score:    0, Epsilon: 0.012
# Episode 8823, Reward: -490.80, Score:    0, Epsilon: 0.012
# Episode 8824, Reward: -370.55, Score:   18, Epsilon: 0.012
# Episode 8825, Reward: -556.30, Score:    0, Epsilon: 0.012
# Episode 8826, Reward: -500.30, Score:    0, Epsilon: 0.012
# Episode 8827, Reward: -393.72, Score:   16, Epsilon: 0.012
# Episode 8828, Reward: -520.70, Score:    0, Epsilon: 0.012
# Episode 8829, Reward: -414.45, Score:   50, Epsilon: 0.012
# Episode 8830, Reward: -489.80, Score:    0, Epsilon: 0.012
# Episode 8831, Reward: -467.92, Score:   16, Epsilon: 0.012
# Episode 8832, Reward: -314.38, Score:   42, Epsilon: 0.012
# Episode 8833, Reward: -620.10, Score:    0, Epsilon: 0.012
# Episode 8834, Reward: -366.58, Score:  130, Epsilon: 0.012
# Episode 8835, Reward: -546.31, Score:  170, Epsilon: 0.012
# Episode 8836, Reward: -205.69, Score:  268, Epsilon: 0.012
# Episode 8837, Reward: -399.09, Score:  226, Epsilon: 0.012
# Episode 8838, Reward:  208.67, Score:  556, Epsilon: 0.012
# Episode 8839, Reward: -407.76, Score:  268, Epsilon: 0.012
# Episode 8840, Reward: -515.40, Score:  248, Epsilon: 0.012
# Checkpoint saved at episode 8840, best score: 5848.00
# Loaded checkpoint from episode 8840, best score: 5848.00, epsilon=0.012
# Episode 8841, Reward:  162.18, Score:  446, Epsilon: 0.012
# Episode 8842, Reward: -418.49, Score:  482, Epsilon: 0.012
# Episode 8843, Reward: -652.25, Score:  346, Epsilon: 0.012
# Episode 8844, Reward:  166.83, Score:  746, Epsilon: 0.012
# Episode 8845, Reward: -122.11, Score:  734, Epsilon: 0.012
# Episode 8846, Reward: 1759.37, Score: 1060, Epsilon: 0.012
# Episode 8847, Reward:  665.33, Score:  776, Epsilon: 0.012
# Episode 8848, Reward: 1320.10, Score:  872, Epsilon: 0.012
# Episode 8849, Reward: -265.73, Score:  436, Epsilon: 0.012
# Episode 8850, Reward: -528.77, Score:  330, Epsilon: 0.012
# Episode 8851, Reward: 2296.33, Score: 1264, Epsilon: 0.012
# Episode 8852, Reward: 1052.51, Score:  664, Epsilon: 0.012
# Episode 8853, Reward: -584.28, Score:  136, Epsilon: 0.012
# Episode 8854, Reward: -254.23, Score:  272, Epsilon: 0.012
# Episode 8855, Reward: -531.06, Score:  128, Epsilon: 0.012
# Episode 8856, Reward: -191.22, Score:  344, Epsilon: 0.012
# Episode 8857, Reward:  165.66, Score:  358, Epsilon: 0.012
# Episode 8858, Reward: -664.69, Score:   42, Epsilon: 0.012
# Episode 8859, Reward: -247.31, Score:  302, Epsilon: 0.012
# Episode 8860, Reward: -298.47, Score:  200, Epsilon: 0.012
# Checkpoint saved at episode 8860, best score: 5848.00
# Loaded checkpoint from episode 8860, best score: 5848.00, epsilon=0.012
# Episode 8861, Reward:   79.26, Score:  330, Epsilon: 0.012
# Episode 8862, Reward: -520.50, Score:   42, Epsilon: 0.012
# Episode 8863, Reward: -442.30, Score:    0, Epsilon: 0.012
# Episode 8864, Reward: -522.80, Score:    0, Epsilon: 0.012
# Episode 8865, Reward: -441.18, Score:   16, Epsilon: 0.012
# Episode 8866, Reward: -449.10, Score:    0, Epsilon: 0.012
# Episode 8867, Reward: -569.00, Score:    0, Epsilon: 0.012
# Episode 8868, Reward: -506.18, Score:   16, Epsilon: 0.012
# Episode 8869, Reward: -572.60, Score:    0, Epsilon: 0.012
# Episode 8870, Reward: -555.63, Score:  210, Epsilon: 0.012
# Episode 8871, Reward: -449.00, Score:   50, Epsilon: 0.012
# Episode 8872, Reward: -476.85, Score:   50, Epsilon: 0.012
# Episode 8873, Reward: -622.98, Score:   64, Epsilon: 0.012
# Episode 8874, Reward: -705.10, Score:    0, Epsilon: 0.012
# Episode 8875, Reward: -121.99, Score:  304, Epsilon: 0.012
# Episode 8876, Reward: -652.95, Score:   30, Epsilon: 0.012
# Episode 8877, Reward: -327.57, Score:  372, Epsilon: 0.012
# Episode 8878, Reward: -307.27, Score:  310, Epsilon: 0.012
# Episode 8879, Reward: -421.00, Score:  160, Epsilon: 0.012
# Episode 8880, Reward: -130.35, Score:  324, Epsilon: 0.012
# Checkpoint saved at episode 8880, best score: 5848.00
# Loaded checkpoint from episode 8880, best score: 5848.00, epsilon=0.012
# Episode 8881, Reward:   -3.27, Score:  380, Epsilon: 0.012
# Episode 8882, Reward: -473.80, Score:    0, Epsilon: 0.012
# Episode 8883, Reward: -378.99, Score:   92, Epsilon: 0.012
# Episode 8884, Reward: -477.60, Score:    0, Epsilon: 0.012
# Episode 8885, Reward: -338.27, Score:   42, Epsilon: 0.012
# Episode 8886, Reward: -521.60, Score:    0, Epsilon: 0.012
# Episode 8887, Reward: -427.00, Score:    0, Epsilon: 0.012
# Episode 8888, Reward: -246.30, Score:   50, Epsilon: 0.012
# Episode 8889, Reward: -421.19, Score:   18, Epsilon: 0.012
# Episode 8890, Reward: -347.30, Score:    0, Epsilon: 0.012
# Episode 8891, Reward: -469.62, Score:   16, Epsilon: 0.012
# Episode 8892, Reward: -405.55, Score:   42, Epsilon: 0.012
# Episode 8893, Reward: -558.30, Score:    0, Epsilon: 0.012
# Episode 8894, Reward: -329.57, Score:   42, Epsilon: 0.012
# Episode 8895, Reward: -496.00, Score:    0, Epsilon: 0.012
# Episode 8896, Reward: -463.75, Score:   50, Epsilon: 0.012
# Episode 8897, Reward: -572.00, Score:    0, Epsilon: 0.012
# Episode 8898, Reward: -434.80, Score:    0, Epsilon: 0.012
# Episode 8899, Reward: -560.10, Score:    0, Epsilon: 0.012
# Episode 8900, Reward: -482.80, Score:    0, Epsilon: 0.012
# Checkpoint saved at episode 8900, best score: 5848.00
# Loaded checkpoint from episode 8900, best score: 5848.00, epsilon=0.012
# Episode 8901, Reward:  193.59, Score:  382, Epsilon: 0.012
# Episode 8902, Reward: -374.31, Score:   92, Epsilon: 0.012
# Episode 8903, Reward: -395.59, Score:   18, Epsilon: 0.012
# Episode 8904, Reward: -367.76, Score:   16, Epsilon: 0.012
# Episode 8905, Reward:  -74.53, Score:  410, Epsilon: 0.012
# Episode 8906, Reward:   37.23, Score:  596, Epsilon: 0.012
# Episode 8907, Reward:  206.77, Score:  608, Epsilon: 0.012
# Episode 8908, Reward: -607.80, Score:  150, Epsilon: 0.012
# Episode 8909, Reward: -203.47, Score:  444, Epsilon: 0.012
# Episode 8910, Reward: -423.54, Score:  294, Epsilon: 0.012
# Episode 8911, Reward:  927.00, Score:  842, Epsilon: 0.012
# Episode 8912, Reward:  449.33, Score:  568, Epsilon: 0.012
# Episode 8913, Reward: 1387.19, Score:  942, Epsilon: 0.012
# Episode 8914, Reward:   43.24, Score:  518, Epsilon: 0.012
# Episode 8915, Reward: 1200.95, Score:  624, Epsilon: 0.012
# Episode 8916, Reward:  229.43, Score:  482, Epsilon: 0.012
# Episode 8917, Reward: -659.67, Score:   52, Epsilon: 0.012
# Episode 8918, Reward: -558.51, Score:  160, Epsilon: 0.012
# Episode 8919, Reward: -446.03, Score:  160, Epsilon: 0.012
# Episode 8920, Reward: -625.69, Score:   84, Epsilon: 0.012
# Checkpoint saved at episode 8920, best score: 5848.00
# Loaded checkpoint from episode 8920, best score: 5848.00, epsilon=0.012
# Episode 8921, Reward:  -47.13, Score:  416, Epsilon: 0.012
# Episode 8922, Reward: -353.30, Score:    0, Epsilon: 0.012
# Episode 8923, Reward: -576.80, Score:    0, Epsilon: 0.012
# Episode 8924, Reward: -479.60, Score:    0, Epsilon: 0.012
# Episode 8925, Reward: -595.10, Score:    0, Epsilon: 0.012
# Episode 8926, Reward: -116.40, Score:   60, Epsilon: 0.012
# Episode 8927, Reward: -591.30, Score:    0, Epsilon: 0.012
# Episode 8928, Reward: -454.26, Score:   16, Epsilon: 0.012
# Episode 8929, Reward: -509.61, Score:   42, Epsilon: 0.011
# Episode 8930, Reward: -203.22, Score:  318, Epsilon: 0.011
# Episode 8931, Reward: -482.80, Score:    0, Epsilon: 0.011
# Episode 8932, Reward: -320.13, Score:  156, Epsilon: 0.011
# Episode 8933, Reward: -707.56, Score:  172, Epsilon: 0.011
# Episode 8934, Reward: -325.83, Score:  202, Epsilon: 0.011
# Episode 8935, Reward: -415.41, Score:   96, Epsilon: 0.011
# Episode 8936, Reward: -177.58, Score:  176, Epsilon: 0.011
# Episode 8937, Reward: -378.65, Score:  168, Epsilon: 0.011
# Episode 8938, Reward: -382.22, Score:  288, Epsilon: 0.011
# Episode 8939, Reward:  -28.49, Score:  428, Epsilon: 0.011
# Episode 8940, Reward: -458.82, Score:  282, Epsilon: 0.011
# Checkpoint saved at episode 8940, best score: 5848.00
# Loaded checkpoint from episode 8940, best score: 5848.00, epsilon=0.011
# Episode 8941, Reward: -256.93, Score:  118, Epsilon: 0.011
# Episode 8942, Reward: -326.78, Score:   32, Epsilon: 0.011
# Episode 8943, Reward: -542.30, Score:    0, Epsilon: 0.011
# Episode 8944, Reward: -462.80, Score:    0, Epsilon: 0.011
# Episode 8945, Reward: -558.70, Score:   10, Epsilon: 0.011
# Episode 8946, Reward: -242.53, Score:   94, Epsilon: 0.011
# Episode 8947, Reward: -537.80, Score:    0, Epsilon: 0.011
# Episode 8948, Reward: -494.35, Score:   50, Epsilon: 0.011
# Episode 8949, Reward: -468.43, Score:  360, Epsilon: 0.011
# Episode 8950, Reward: -303.01, Score:  412, Epsilon: 0.011
# Episode 8951, Reward:   21.64, Score:  474, Epsilon: 0.011
# Episode 8952, Reward: -608.62, Score:  126, Epsilon: 0.011
# Episode 8953, Reward:  562.84, Score:  604, Epsilon: 0.011
# Episode 8954, Reward: -405.11, Score:  280, Epsilon: 0.011
# Episode 8955, Reward: -454.71, Score:  328, Epsilon: 0.011
# Episode 8956, Reward: -197.02, Score:  306, Epsilon: 0.011
# Episode 8957, Reward: -281.46, Score:  394, Epsilon: 0.011
# Episode 8958, Reward: -515.35, Score:  184, Epsilon: 0.011
# Episode 8959, Reward: -310.95, Score:  338, Epsilon: 0.011
# Episode 8960, Reward: -517.43, Score:  178, Epsilon: 0.011
# Checkpoint saved at episode 8960, best score: 5848.00
# Loaded checkpoint from episode 8960, best score: 5848.00, epsilon=0.011
# Episode 8961, Reward: -172.48, Score:  346, Epsilon: 0.011
# Episode 8962, Reward:  248.25, Score:  898, Epsilon: 0.011
# Episode 8963, Reward: -685.22, Score:  384, Epsilon: 0.011
# Episode 8964, Reward: -533.67, Score:  422, Epsilon: 0.011
# Episode 8965, Reward: -733.64, Score:  196, Epsilon: 0.011
# Episode 8966, Reward: -236.74, Score:  288, Epsilon: 0.011
# Episode 8967, Reward: -670.80, Score:  236, Epsilon: 0.011
# Episode 8968, Reward: -516.59, Score:  164, Epsilon: 0.011
# Episode 8969, Reward:  339.23, Score:  438, Epsilon: 0.011
# Episode 8970, Reward: -223.46, Score:  248, Epsilon: 0.011
# Episode 8971, Reward:  910.10, Score:  688, Epsilon: 0.011
# Episode 8972, Reward:  -60.09, Score:  334, Epsilon: 0.011
# Episode 8973, Reward: -450.83, Score:  136, Epsilon: 0.011
# Episode 8974, Reward: -470.74, Score:  248, Epsilon: 0.011
# Episode 8975, Reward: -462.25, Score:  144, Epsilon: 0.011
# Episode 8976, Reward: -573.55, Score:  102, Epsilon: 0.011
# Episode 8977, Reward: -219.21, Score:  236, Epsilon: 0.011
# Episode 8978, Reward:  505.29, Score:  530, Epsilon: 0.011
# Episode 8979, Reward: 1661.14, Score:  902, Epsilon: 0.011
# Episode 8980, Reward: -479.21, Score:  310, Epsilon: 0.011
# Checkpoint saved at episode 8980, best score: 5848.00
# Loaded checkpoint from episode 8980, best score: 5848.00, epsilon=0.011
# Episode 8981, Reward: -159.95, Score:  246, Epsilon: 0.011
# Episode 8982, Reward: -334.59, Score:   18, Epsilon: 0.011
# Episode 8983, Reward: -541.80, Score:    0, Epsilon: 0.011
# Episode 8984, Reward: -544.30, Score:    0, Epsilon: 0.011
# Episode 8985, Reward: -477.80, Score:    0, Epsilon: 0.011
# Episode 8986, Reward: -527.80, Score:    0, Epsilon: 0.011
# Episode 8987, Reward: -461.76, Score:   16, Epsilon: 0.011
# Episode 8988, Reward: -683.02, Score:  294, Epsilon: 0.011
# Episode 8989, Reward: -663.83, Score:  212, Epsilon: 0.011
# Episode 8990, Reward: -517.98, Score:  214, Epsilon: 0.011
# Episode 8991, Reward:  489.28, Score:  578, Epsilon: 0.011
# Episode 8992, Reward:  135.96, Score:  510, Epsilon: 0.011
# Episode 8993, Reward:  713.17, Score:  674, Epsilon: 0.011
# Episode 8994, Reward: -324.30, Score:  230, Epsilon: 0.011
# Episode 8995, Reward: -527.71, Score:  188, Epsilon: 0.011
# Episode 8996, Reward: -523.92, Score:  174, Epsilon: 0.011
# Episode 8997, Reward: -535.16, Score:  278, Epsilon: 0.011
# Episode 8998, Reward: 1357.16, Score:  724, Epsilon: 0.011
# Episode 8999, Reward:  773.23, Score:  656, Epsilon: 0.011
# Episode 9000, Reward: 1137.57, Score:  806, Epsilon: 0.011
# Checkpoint saved at episode 9000, best score: 5848.00
# Loaded checkpoint from episode 9000, best score: 5848.00, epsilon=0.011
# Episode 9001, Reward:  -94.07, Score:  268, Epsilon: 0.011
# Episode 9002, Reward: -472.60, Score:    0, Epsilon: 0.011
# Episode 9003, Reward: -552.00, Score:    0, Epsilon: 0.011
# Episode 9004, Reward: -479.45, Score:   50, Epsilon: 0.011
# Episode 9005, Reward: -360.70, Score:    0, Epsilon: 0.011
# Episode 9006, Reward: -307.26, Score:   42, Epsilon: 0.011
# Episode 9007, Reward: -526.00, Score:    0, Epsilon: 0.011
# Episode 9008, Reward: -449.80, Score:    0, Epsilon: 0.011
# Episode 9009, Reward: -480.37, Score:   42, Epsilon: 0.011
# Episode 9010, Reward: -566.60, Score:    0, Epsilon: 0.011
# Episode 9011, Reward: -489.58, Score:   42, Epsilon: 0.011
# Episode 9012, Reward: -184.32, Score:   66, Epsilon: 0.011
# Episode 9013, Reward: -312.48, Score:   36, Epsilon: 0.011
# Episode 9014, Reward: -501.97, Score:   60, Epsilon: 0.011
# Episode 9015, Reward:  103.53, Score:  600, Epsilon: 0.011
# Episode 9016, Reward: -480.63, Score:  440, Epsilon: 0.011
# Episode 9017, Reward: -543.68, Score:  178, Epsilon: 0.011
# Episode 9018, Reward:  755.48, Score:  724, Epsilon: 0.011
# Episode 9019, Reward: -199.01, Score:  416, Epsilon: 0.011
# Episode 9020, Reward: -156.82, Score:  338, Epsilon: 0.011
# Checkpoint saved at episode 9020, best score: 5848.00
# Loaded checkpoint from episode 9020, best score: 5848.00, epsilon=0.011
# Episode 9021, Reward: -583.08, Score:  152, Epsilon: 0.011
# Episode 9022, Reward:  -32.08, Score:  856, Epsilon: 0.011
# Episode 9023, Reward: -1066.98, Score:   64, Epsilon: 0.011
# Episode 9024, Reward: -123.72, Score:  398, Epsilon: 0.011
# Episode 9025, Reward: -660.87, Score:  374, Epsilon: 0.011
# Episode 9026, Reward: -601.84, Score:  254, Epsilon: 0.011
# Episode 9027, Reward: -841.52, Score:  142, Epsilon: 0.011
# Episode 9028, Reward: -629.19, Score:  136, Epsilon: 0.011
# Episode 9029, Reward: -251.06, Score:  210, Epsilon: 0.011
# Episode 9030, Reward: -720.81, Score:   82, Epsilon: 0.011
# Episode 9031, Reward: -618.57, Score:  168, Epsilon: 0.011
# Episode 9032, Reward: -306.97, Score:  330, Epsilon: 0.011
# Episode 9033, Reward:  420.54, Score:  660, Epsilon: 0.011
# Episode 9034, Reward: -325.22, Score:  328, Epsilon: 0.011
# Episode 9035, Reward: -624.24, Score:  124, Epsilon: 0.011
# Episode 9036, Reward: -103.46, Score:  422, Epsilon: 0.011
# Episode 9037, Reward: -689.59, Score:   84, Epsilon: 0.011
# Episode 9038, Reward: -517.02, Score:  178, Epsilon: 0.011
# Episode 9039, Reward: -647.03, Score:  160, Epsilon: 0.011
# Episode 9040, Reward: -545.82, Score:  142, Epsilon: 0.011
# Checkpoint saved at episode 9040, best score: 5848.00
# Loaded checkpoint from episode 9040, best score: 5848.00, epsilon=0.011
# Episode 9041, Reward: -258.87, Score:  270, Epsilon: 0.011
# Episode 9042, Reward: -421.80, Score:   10, Epsilon: 0.011
# Episode 9043, Reward: -516.24, Score:   16, Epsilon: 0.011
# Episode 9044, Reward: -481.80, Score:    0, Epsilon: 0.011
# Episode 9045, Reward: -302.55, Score:  100, Epsilon: 0.011
# Episode 9046, Reward: -487.30, Score:    0, Epsilon: 0.011
# Episode 9047, Reward: -509.61, Score:   28, Epsilon: 0.011
# Episode 9048, Reward: -372.10, Score:   68, Epsilon: 0.011
# Episode 9049, Reward: -553.60, Score:    0, Epsilon: 0.011
# Episode 9050, Reward: -537.40, Score:    0, Epsilon: 0.011
# Episode 9051, Reward: -501.10, Score:    0, Epsilon: 0.011
# Episode 9052, Reward: -635.50, Score:    0, Epsilon: 0.011
# Episode 9053, Reward: -558.17, Score:  110, Epsilon: 0.011
# Episode 9054, Reward: -282.73, Score:  348, Epsilon: 0.011
# Episode 9055, Reward: -511.77, Score:  124, Epsilon: 0.011
# Episode 9056, Reward: -433.35, Score:  248, Epsilon: 0.011
# 在目前儲存格或上一個儲存格中執行程式碼時，Kernel 已損毀。
#
# 請檢閱儲存格中的程式碼，找出失敗的可能原因。
#
# 如需詳細資訊，請按一下<a href='https://aka.ms/vscodeJupyterKernelCrash'>這裡</a>。
#
# 如需詳細資料，請檢視 Jupyter <a href='command:jupyter.viewOutput'>記錄</a>。

# %%
from scipy.ndimage import gaussian_filter1d

reward_smooth = gaussian_filter1d(reward_history, sigma=50)
score_smooth = gaussian_filter1d(score_history, sigma=50)

# 畫圖
# plt.figure(figsize=(10, 5))
plt.plot(reward_history, label='Total Reward', alpha=0.8)
plt.plot(score_history, label='Score', alpha=0.8)
plt.plot(reward_smooth, label='Smoothed Total Reward', linewidth=2)
plt.plot(score_smooth, label='Smoothed Score', linewidth=2)

plt.legend(loc='upper left')
plt.xlabel("Episode")
plt.ylabel("Value")
plt.title("Training Reward Over Episodes")
plt.grid(True)
plt.tight_layout()
# plt.savefig("dqn_training_curve.png")
